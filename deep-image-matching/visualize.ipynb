# %%
import os
import itertools
import pandas as pd
from pathlib import Path
import shutil
import subprocess
import sys
import h5py
import numpy as np
import cv2
import matplotlib.pyplot as plt
from datetime import datetime

class SignatureMatchingSystem:
    def __init__(self, real_data_dir="real_data", temp_dir="temp_matching", results_dir="matching_results"):
        self.real_data_dir = Path(real_data_dir)
        self.temp_dir = Path(temp_dir)
        self.results_dir = Path(results_dir)
        
        # Create necessary directories
        self.temp_dir.mkdir(exist_ok=True)
        self.results_dir.mkdir(exist_ok=True)
        
        # Results tracking
        self.results_log = []
        
    def get_all_image_pairs(self):
        """Generate all possible pairs of images across all subfolders"""
        all_images = []
        
        # Collect all images with their person ID
        for person_folder in self.real_data_dir.iterdir():
            if person_folder.is_dir():
                person_id = person_folder.name
                for img_file in person_folder.iterdir():
                    if img_file.suffix.lower() in ['.png', '.jpg', '.jpeg']:
                        all_images.append({
                            'person_id': person_id,
                            'image_path': img_file,
                            'image_name': img_file.name,
                            'full_name': f"{person_id}_{img_file.name}"
                        })
        
        # Generate all pairs
        pairs = []
        for img1, img2 in itertools.combinations(all_images, 2):
            pairs.append({
                'img1': img1,
                'img2': img2,
                'same_person': img1['person_id'] == img2['person_id'],
                'pair_name': f"{img1['full_name']}_vs_{img2['full_name']}"
            })
            
        return pairs
    
    def create_pair_batch(self, pairs, batch_size=50):
        """Create batches of pairs for processing"""
        for i in range(0, len(pairs), batch_size):
            yield pairs[i:i + batch_size]
    
    def setup_batch_directory(self, batch_pairs, batch_id):
        """Setup batch directory with proper structure for main.py"""
        batch_temp_dir = self.temp_dir / f"batch_{batch_id}"
        
        # Clean up existing directory
        if batch_temp_dir.exists():
            shutil.rmtree(batch_temp_dir)
        batch_temp_dir.mkdir(exist_ok=True)
        
        # Create 'images' subdirectory as expected by main.py
        images_dir = batch_temp_dir / "images"
        images_dir.mkdir(exist_ok=True)
        
        # Copy images to images subdirectory
        copied_images = set()
        pair_lines = []
        
        for pair in batch_pairs:
            # Copy images if not already copied
            for img_key in ['img1', 'img2']:
                img_info = pair[img_key]
                new_name = img_info['full_name']
                
                if new_name not in copied_images:
                    src_path = img_info['image_path']
                    dst_path = images_dir / new_name
                    shutil.copy2(src_path, dst_path)
                    copied_images.add(new_name)
            
            # Add pair to pairs.txt
            pair_lines.append(f"{pair['img1']['full_name']} {pair['img2']['full_name']}")
        
        # Write pairs.txt in batch directory
        pairs_file = batch_temp_dir / "pairs.txt"
        with open(pairs_file, 'w') as f:
            f.write('\n'.join(pair_lines))
        
        return batch_temp_dir, len(pair_lines)
    
    def run_matching_for_batch(self, batch_temp_dir):
        """Run the main.py script for a batch with corrected command"""
        original_cwd = os.getcwd()
        
        try:
            # Change to batch directory and run main.py from original location
            cmd = [
                sys.executable, 
                str(Path(original_cwd) / "main.py"),  # Full path to main.py
                "-d", ".",  # Current directory (batch directory)
                "-p", "superpoint+lightglue",
                "-s", "custom_pairs",
                "--pair_file", "pairs.txt",
                "-f"
            ]
            
            print(f"Running command from {batch_temp_dir}: {' '.join(cmd)}")
            
            # Run from batch directory
            result = subprocess.run(cmd, capture_output=True, text=True, cwd=str(batch_temp_dir))
            
            if result.returncode != 0:
                print(f"Error running matching: {result.stderr}")
                print(f"stdout: {result.stdout}")
                return False
            else:
                print(f"Matching completed successfully")
                print(f"stdout: {result.stdout}")
            
            return True
            
        except Exception as e:
            print(f"Exception during matching: {e}")
            return False
    
    def load_keypoints_and_scores(self, h5file, image_name):
        """Load keypoints and their confidence scores from features file"""
        try:
            with h5py.File(h5file, "r") as f:
                if image_name in f:
                    keypoints = f[image_name]["keypoints"][()]
                    scores = f[image_name]["scores"][()]
                    return keypoints, scores
                else:
                    return None, None
        except Exception as e:
            print(f"Error loading keypoints for {image_name}: {e}")
            return None, None
    
    def load_matches(self, h5file, image_name1, image_name2):
        """Load matches between two images with proper error handling"""
        try:
            with h5py.File(h5file, "r") as f:
                # Try both orders
                if image_name1 in f and image_name2 in f[image_name1]:
                    matches = f[image_name1][image_name2][()]
                    return matches if len(matches) > 0 else None
                elif image_name2 in f and image_name1 in f[image_name2]:
                    matches = f[image_name2][image_name1][()]
                    return matches if len(matches) > 0 else None
                else:
                    return None
        except Exception as e:
            print(f"Error loading matches between {image_name1} and {image_name2}: {e}")
            return None
    
    def create_signature_mask(self, image_path, blur_kernel=3, threshold_value=240):
        """Create a binary mask to identify signature regions"""
        try:
            img = cv2.imread(str(image_path), cv2.IMREAD_GRAYSCALE)
            if img is None:
                return None
            
            blurred = cv2.GaussianBlur(img, (blur_kernel, blur_kernel), 0)
            _, mask = cv2.threshold(blurred, threshold_value, 255, cv2.THRESH_BINARY_INV)
            
            kernel = np.ones((3, 3), np.uint8)
            mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
            mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
            
            return mask
        except Exception as e:
            print(f"Error creating mask for {image_path}: {e}")
            return None
    
    def filter_keypoints_by_signature(self, keypoints, scores, mask, dilation_radius=10):
        """Filter keypoints to keep only those that lie on or near signature strokes"""
        if mask is None or len(keypoints) == 0:
            return np.array([]), np.array([]), np.array([])
        
        try:
            kernel = cv2.getStructuringElement(
                cv2.MORPH_ELLIPSE, (dilation_radius * 2 + 1, dilation_radius * 2 + 1)
            )
            dilated_mask = cv2.dilate(mask, kernel, iterations=1)
            
            valid_indices = []
            for i, (x, y) in enumerate(keypoints):
                x_int, y_int = int(round(x)), int(round(y))
                if 0 <= x_int < dilated_mask.shape[1] and 0 <= y_int < dilated_mask.shape[0]:
                    if dilated_mask[y_int, x_int] > 0:
                        valid_indices.append(i)
            
            valid_indices = np.array(valid_indices)
            
            if len(valid_indices) > 0:
                filtered_keypoints = keypoints[valid_indices]
                filtered_scores = scores[valid_indices]
                return filtered_keypoints, filtered_scores, valid_indices
            else:
                return np.array([]), np.array([]), np.array([])
        except Exception as e:
            print(f"Error filtering keypoints: {e}")
            return np.array([]), np.array([]), np.array([])
    
    def filter_matches_by_signature_features(self, matches, valid_indices1, valid_indices2):
        """Filter matches to keep only those between signature features"""
        if matches is None or len(matches) == 0 or len(valid_indices1) == 0 or len(valid_indices2) == 0:
            return np.array([])
        
        try:
            idx1_map = {orig_idx: new_idx for new_idx, orig_idx in enumerate(valid_indices1)}
            idx2_map = {orig_idx: new_idx for new_idx, orig_idx in enumerate(valid_indices2)}
            
            filtered_matches = []
            for match in matches:
                idx1, idx2 = match[0], match[1]
                if idx1 in idx1_map and idx2 in idx2_map:
                    filtered_matches.append([idx1_map[idx1], idx2_map[idx2]])
            
            return np.array(filtered_matches)
        except Exception as e:
            print(f"Error filtering matches: {e}")
            return np.array([])
    
    def visualize_matches(self, img1_path, img2_path, keypoints1, keypoints2, 
                         original_matches, filtered_keypoints1, filtered_keypoints2, 
                         filtered_matches, pair_info, save_path):
        """Create and save visualization of matches"""
        try:
            img1 = cv2.imread(str(img1_path))
            img2 = cv2.imread(str(img2_path))
            
            if img1 is None or img2 is None:
                print(f"Could not load images: {img1_path}, {img2_path}")
                return False
            
            fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 16))
            
            # Plot 1: Original matches
            if original_matches is not None and len(original_matches) > 0:
                kpts1_orig = [cv2.KeyPoint(float(x), float(y), 1) for x, y in keypoints1]
                kpts2_orig = [cv2.KeyPoint(float(x), float(y), 1) for x, y in keypoints2]
                
                cv_matches_orig = [
                    cv2.DMatch(_queryIdx=int(i), _trainIdx=int(j), _distance=0) 
                    for i, j in original_matches
                ]
                
                img_matches_orig = cv2.drawMatches(
                    img1, kpts1_orig, img2, kpts2_orig, cv_matches_orig, None,
                    flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS,
                )
                
                ax1.imshow(cv2.cvtColor(img_matches_orig, cv2.COLOR_BGR2RGB))
                ax1.set_title(f"Original Feature Matches ({len(original_matches)} matches)", fontsize=16)
            else:
                ax1.text(0.5, 0.5, "No original matches found", ha='center', va='center', 
                        transform=ax1.transAxes, fontsize=16)
            ax1.axis("off")
            
            # Plot 2: Signature matches
            if (filtered_matches is not None and len(filtered_matches) > 0 and 
                len(filtered_keypoints1) > 0 and len(filtered_keypoints2) > 0):
                
                kpts1_filt = [cv2.KeyPoint(float(x), float(y), 1) for x, y in filtered_keypoints1]
                kpts2_filt = [cv2.KeyPoint(float(x), float(y), 1) for x, y in filtered_keypoints2]
                
                cv_matches_filt = [
                    cv2.DMatch(_queryIdx=int(i), _trainIdx=int(j), _distance=0) 
                    for i, j in filtered_matches
                ]
                
                img_matches_filt = cv2.drawMatches(
                    img1, kpts1_filt, img2, kpts2_filt, cv_matches_filt, None,
                    flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS,
                )
                
                ax2.imshow(cv2.cvtColor(img_matches_filt, cv2.COLOR_BGR2RGB))
                ax2.set_title(f"Signature Feature Matches ({len(filtered_matches)} matches)", fontsize=16)
            else:
                ax2.text(0.5, 0.5, "No signature matches found", ha='center', va='center', 
                        transform=ax2.transAxes, fontsize=16)
            ax2.axis("off")
            
            # Add pair information
            same_person_text = "SAME PERSON" if pair_info['same_person'] else "DIFFERENT PERSON"
            fig.suptitle(f"{pair_info['pair_name']} - {same_person_text}", fontsize=18, y=0.98)
            
            plt.tight_layout()
            plt.savefig(save_path, dpi=150, bbox_inches='tight')
            plt.close()
            
            return True
            
        except Exception as e:
            print(f"Error creating visualization: {e}")
            return False
    
    def find_results_files(self, batch_temp_dir):
        """Find the results files (features.h5 and matches.h5) in the batch directory"""
        # Look for results directory created by main.py
        results_dirs = list(batch_temp_dir.glob("results_*"))
        
        if results_dirs:
            results_dir = results_dirs[0]  # Take the first (should be only one)
            features_path = results_dir / "features.h5"
            matches_path = results_dir / "matches.h5"
        else:
            # Sometimes files might be created directly in the batch directory
            features_path = batch_temp_dir / "features.h5"
            matches_path = batch_temp_dir / "matches.h5"
        
        return features_path, matches_path
    
    def process_batch_results(self, batch_pairs, batch_temp_dir, batch_id):
        """Process results from a batch"""
        features_path, matches_path = self.find_results_files(batch_temp_dir)
        
        if not features_path.exists() or not matches_path.exists():
            print(f"Missing features ({features_path.exists()}) or matches ({matches_path.exists()}) file for batch {batch_id}")
            print(f"Looking in: {batch_temp_dir}")
            # List all files in the directory for debugging
            print("Files found:")
            for file in batch_temp_dir.rglob("*"):
                print(f"  {file}")
            return
        
        batch_results_dir = self.results_dir / f"batch_{batch_id}"
        batch_results_dir.mkdir(exist_ok=True)
        
        batch_log = []
        
        for pair in batch_pairs:
            try:
                img1_name = pair['img1']['full_name']
                img2_name = pair['img2']['full_name']
                
                print(f"Processing pair: {img1_name} vs {img2_name}")
                
                # Load keypoints
                keypoints1, scores1 = self.load_keypoints_and_scores(features_path, img1_name)
                keypoints2, scores2 = self.load_keypoints_and_scores(features_path, img2_name)
                
                if keypoints1 is None or keypoints2 is None:
                    print(f"Failed to load keypoints for {img1_name} or {img2_name}")
                    continue
                
                # Load matches
                original_matches = self.load_matches(matches_path, img1_name, img2_name)
                
                # Create signature masks
                img1_path = batch_temp_dir / "images" / img1_name
                img2_path = batch_temp_dir / "images" / img2_name
                
                mask1 = self.create_signature_mask(img1_path)
                mask2 = self.create_signature_mask(img2_path)
                
                # Filter keypoints by signature regions
                filt_kpts1, filt_scores1, valid_idx1 = self.filter_keypoints_by_signature(
                    keypoints1, scores1, mask1
                )
                filt_kpts2, filt_scores2, valid_idx2 = self.filter_keypoints_by_signature(
                    keypoints2, scores2, mask2
                )
                
                # Filter matches
                filtered_matches = self.filter_matches_by_signature_features(
                    original_matches, valid_idx1, valid_idx2
                )
                
                # Create visualization
                viz_path = batch_results_dir / f"{pair['pair_name']}.png"
                viz_success = self.visualize_matches(
                    img1_path, img2_path, keypoints1, keypoints2,
                    original_matches, filt_kpts1, filt_kpts2, filtered_matches,
                    pair, viz_path
                )
                
                # Log results
                result_entry = {
                    'pair_name': pair['pair_name'],
                    'img1': img1_name,
                    'img2': img2_name,
                    'same_person': pair['same_person'],
                    'person1_id': pair['img1']['person_id'],
                    'person2_id': pair['img2']['person_id'],
                    'original_features_1': len(keypoints1),
                    'original_features_2': len(keypoints2),
                    'signature_features_1': len(filt_kpts1),
                    'signature_features_2': len(filt_kpts2),
                    'original_matches': len(original_matches) if original_matches is not None else 0,
                    'signature_matches': len(filtered_matches) if filtered_matches is not None else 0,
                    'visualization_created': viz_success,
                    'batch_id': batch_id,
                    'timestamp': datetime.now().isoformat()
                }
                
                batch_log.append(result_entry)
                self.results_log.append(result_entry)
                
                print(f"  Original matches: {result_entry['original_matches']}")
                print(f"  Signature matches: {result_entry['signature_matches']}")
                
            except Exception as e:
                print(f"Error processing pair {pair['pair_name']}: {e}")
                continue
        
        # Save batch results
        if batch_log:
            batch_df = pd.DataFrame(batch_log)
            batch_df.to_csv(batch_results_dir / "batch_results.csv", index=False)
    
    def run_comprehensive_matching(self, batch_size=20):
        """Run comprehensive signature matching across all pairs"""
        print("Starting comprehensive signature matching...")
        
        # Get all possible pairs
        all_pairs = self.get_all_image_pairs()
        print(f"Total pairs to process: {len(all_pairs)}")
        
        same_person_pairs = sum(1 for p in all_pairs if p['same_person'])
        different_person_pairs = len(all_pairs) - same_person_pairs
        print(f"Same person pairs: {same_person_pairs}")
        print(f"Different person pairs: {different_person_pairs}")
        
        # Process in batches
        for batch_id, batch_pairs in enumerate(self.create_pair_batch(all_pairs, batch_size)):
            print(f"\nProcessing batch {batch_id + 1} ({len(batch_pairs)} pairs)...")
            
            try:
                # Setup batch directory
                batch_temp_dir, num_pairs = self.setup_batch_directory(batch_pairs, batch_id)
                print(f"Setup completed for {num_pairs} pairs in {batch_temp_dir}")
                
                # Run matching
                success = self.run_matching_for_batch(batch_temp_dir)
                if not success:
                    print(f"Matching failed for batch {batch_id}")
                    continue
                
                # Process results
                self.process_batch_results(batch_pairs, batch_temp_dir, batch_id)
                
                # Clean up temporary files (optional - comment out for debugging)
                # shutil.rmtree(batch_temp_dir)
                
            except Exception as e:
                print(f"Error processing batch {batch_id}: {e}")
                continue
        
        # Save comprehensive results
        if self.results_log:
            comprehensive_df = pd.DataFrame(self.results_log)
            comprehensive_df.to_csv(self.results_dir / "comprehensive_results.csv", index=False)
            
            # Generate summary statistics
            self.generate_summary_report(comprehensive_df)
        else:
            print("No results to save!")
    
    def generate_summary_report(self, df):
        """Generate a summary report of matching results"""
        summary = {
            'total_pairs': len(df),
            'same_person_pairs': len(df[df['same_person'] == True]),
            'different_person_pairs': len(df[df['same_person'] == False]),
            'pairs_with_original_matches': len(df[df['original_matches'] > 0]),
            'pairs_with_signature_matches': len(df[df['signature_matches'] > 0]),
            'avg_original_matches_same_person': df[df['same_person'] == True]['original_matches'].mean(),
            'avg_original_matches_different_person': df[df['same_person'] == False]['original_matches'].mean(),
            'avg_signature_matches_same_person': df[df['same_person'] == True]['signature_matches'].mean(),
            'avg_signature_matches_different_person': df[df['same_person'] == False]['signature_matches'].mean(),
        }
        
        # Save summary
        summary_df = pd.DataFrame([summary])
        summary_df.to_csv(self.results_dir / "summary_report.csv", index=False)
        
        # Print summary
        print("\n" + "="*60)
        print("COMPREHENSIVE MATCHING SUMMARY")
        print("="*60)
        for key, value in summary.items():
            print(f"{key.replace('_', ' ').title()}: {value:.2f}" if isinstance(value, float) else f"{key.replace('_', ' ').title()}: {value}")
        print("="*60)


# Usage
if __name__ == "__main__":
    # Initialize the matching system
    matcher = SignatureMatchingSystem(
        real_data_dir="real_data",
        temp_dir="temp_matching", 
        results_dir="matching_results"
    )
    
    # Run comprehensive matching
    matcher.run_comprehensive_matching(batch_size=20)
# Out:
# Starting comprehensive signature matching...
# Total pairs to process: 378
# Same person pairs: 74
# Different person pairs: 304
#
# Processing batch 1 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_0
# Running command from temp_matching/batch_0: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/21 [00:00<?, ?it/s]
#   5%|▍         | 1/21 [00:00<00:11,  1.80it/s]
#  19%|█▉        | 4/21 [00:00<00:02,  7.57it/s]
#  43%|████▎     | 9/21 [00:00<00:00, 15.98it/s]
#  67%|██████▋   | 14/21 [00:00<00:00, 23.13it/s]
# 100%|██████████| 21/21 [00:01<00:00, 33.59it/s]
# 100%|██████████| 21/21 [00:01<00:00, 20.74it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:08,  2.37it/s]
#  15%|█▌        | 3/20 [00:00<00:03,  5.57it/s]
#  25%|██▌       | 5/20 [00:00<00:01,  7.70it/s]
#  35%|███▌      | 7/20 [00:00<00:01,  8.87it/s]
#  55%|█████▌    | 11/20 [00:01<00:00, 14.98it/s]
#  65%|██████▌   | 13/20 [00:01<00:00, 15.83it/s]
#  75%|███████▌  | 15/20 [00:01<00:00, 16.62it/s]
#  85%|████████▌ | 17/20 [00:01<00:00, 17.43it/s]
#  95%|█████████▌| 19/20 [00:01<00:00, 17.99it/s]
# 100%|██████████| 20/20 [00:01<00:00, 12.97it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:17:50 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:17:51 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:17:51 | [INFO    ]   Image folder: images
# 2025-06-09 10:17:51 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:17:51 | [INFO    ]   Number of images: 21
# 2025-06-09 10:17:51 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:17:51 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:17:51 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:17:51 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:17:51 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:17:51 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:17:51 | [INFO    ]   CUDA available: True
# 2025-06-09 10:17:51 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:17:51 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:17:52 | [INFO    ] Features extracted!
# 2025-06-09 10:17:52 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:17:52 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:17:52 | [INFO    ] Matching features...
# 2025-06-09 10:17:52 | [INFO    ]
#
# Matching failed for batch 0
#
# Processing batch 2 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_1
# Running command from temp_matching/batch_1: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:08,  2.48it/s]
#  23%|██▎       | 5/22 [00:00<00:01, 12.17it/s]
#  50%|█████     | 11/22 [00:00<00:00, 24.50it/s]
#  86%|████████▋ | 19/22 [00:00<00:00, 37.95it/s]
# 100%|██████████| 22/22 [00:00<00:00, 28.50it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.37it/s]
#  15%|█▌        | 3/20 [00:00<00:01,  8.64it/s]
#  30%|███       | 6/20 [00:00<00:00, 15.28it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 15.19it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 14.34it/s]
#  65%|██████▌   | 13/20 [00:01<00:00, 13.45it/s]
#  85%|████████▌ | 17/20 [00:01<00:00, 19.10it/s]
# 100%|██████████| 20/20 [00:01<00:00, 19.19it/s]
# 100%|██████████| 20/20 [00:01<00:00, 15.48it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:17:57 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:17:57 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:17:57 | [INFO    ]   Image folder: images
# 2025-06-09 10:17:57 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:17:57 | [INFO    ]   Number of images: 22
# 2025-06-09 10:17:57 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:17:57 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:17:57 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:17:57 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:17:57 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:17:57 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:17:57 | [INFO    ]   CUDA available: True
# 2025-06-09 10:17:57 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:17:57 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:17:58 | [INFO    ] Features extracted!
# 2025-06-09 10:17:58 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:17:58 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:17:58 | [INFO    ] Matching features...
# 2025-06-09 10:17:58 | [INFO    ]
#
# Matching failed for batch 1
#
# Processing batch 3 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_2
# Running command from temp_matching/batch_2: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:06,  3.47it/s]
#  23%|██▎       | 5/22 [00:00<00:01, 14.94it/s]
#  45%|████▌     | 10/22 [00:00<00:00, 25.02it/s]
#  77%|███████▋  | 17/22 [00:00<00:00, 36.42it/s]
# 100%|██████████| 22/22 [00:00<00:00, 30.82it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.72it/s]
#  15%|█▌        | 3/20 [00:00<00:01,  9.05it/s]
#  25%|██▌       | 5/20 [00:00<00:01, 12.19it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 14.28it/s]
#  50%|█████     | 10/20 [00:00<00:00, 17.39it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 20.68it/s]
#  80%|████████  | 16/20 [00:01<00:00, 17.51it/s]
#  90%|█████████ | 18/20 [00:01<00:00, 15.57it/s]
# 100%|██████████| 20/20 [00:01<00:00, 15.50it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:02 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:02 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:02 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:02 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:02 | [INFO    ]   Number of images: 22
# 2025-06-09 10:18:02 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:02 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:02 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:02 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:02 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:02 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:02 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:02 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:02 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:03 | [INFO    ] Features extracted!
# 2025-06-09 10:18:03 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:03 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:03 | [INFO    ] Matching features...
# 2025-06-09 10:18:03 | [INFO    ]
#
# Matching failed for batch 2
#
# Processing batch 4 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_3
# Running command from temp_matching/batch_3: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:06,  3.45it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 18.30it/s]
#  59%|█████▉    | 13/22 [00:00<00:00, 33.53it/s]
#  95%|█████████▌| 21/22 [00:00<00:00, 46.69it/s]
# 100%|██████████| 22/22 [00:00<00:00, 35.20it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 15.26it/s]
#  20%|██        | 4/20 [00:00<00:00, 17.11it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 19.30it/s]
#  50%|█████     | 10/20 [00:00<00:00, 19.75it/s]
#  70%|███████   | 14/20 [00:00<00:00, 23.53it/s]
#  90%|█████████ | 18/20 [00:00<00:00, 26.29it/s]
# 100%|██████████| 20/20 [00:01<00:00, 17.56it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:07 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:07 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:07 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:07 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:07 | [INFO    ]   Number of images: 22
# 2025-06-09 10:18:07 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:07 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:07 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:07 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:07 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:07 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:07 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:07 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:07 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:08 | [INFO    ] Features extracted!
# 2025-06-09 10:18:08 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:08 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:08 | [INFO    ] Matching features...
# 2025-06-09 10:18:08 | [INFO    ]
#
# Matching failed for batch 3
#
# Processing batch 5 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_4
# Running command from temp_matching/batch_4: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/21 [00:00<?, ?it/s]
#   5%|▍         | 1/21 [00:00<00:05,  3.60it/s]
#  29%|██▊       | 6/21 [00:00<00:00, 19.03it/s]
#  62%|██████▏   | 13/21 [00:00<00:00, 34.23it/s]
# 100%|██████████| 21/21 [00:00<00:00, 47.15it/s]
# 100%|██████████| 21/21 [00:00<00:00, 34.85it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:03,  5.79it/s]
#  25%|██▌       | 5/20 [00:00<00:01, 12.28it/s]
#  40%|████      | 8/20 [00:00<00:00, 15.82it/s]
#  50%|█████     | 10/20 [00:00<00:00, 16.65it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 17.76it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 18.31it/s]
#  90%|█████████ | 18/20 [00:01<00:00, 20.50it/s]
# 100%|██████████| 20/20 [00:01<00:00, 17.37it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:12 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:12 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:12 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:12 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:12 | [INFO    ]   Number of images: 21
# 2025-06-09 10:18:12 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:12 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:12 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:12 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:12 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:12 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:12 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:12 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:12 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:12 | [INFO    ] Features extracted!
# 2025-06-09 10:18:12 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:12 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:12 | [INFO    ] Matching features...
# 2025-06-09 10:18:12 | [INFO    ]
#
# Matching failed for batch 4
#
# Processing batch 6 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_5
# Running command from temp_matching/batch_5: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:06,  3.38it/s]
#  23%|██▎       | 5/22 [00:00<00:01, 14.17it/s]
#  45%|████▌     | 10/22 [00:00<00:00, 23.91it/s]
#  68%|██████▊   | 15/22 [00:00<00:00, 31.40it/s]
# 100%|██████████| 22/22 [00:00<00:00, 42.32it/s]
# 100%|██████████| 22/22 [00:00<00:00, 29.75it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 15.57it/s]
#  20%|██        | 4/20 [00:00<00:01,  8.06it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 13.27it/s]
#  50%|█████     | 10/20 [00:00<00:00, 16.99it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 18.04it/s]
#  80%|████████  | 16/20 [00:00<00:00, 18.94it/s]
#  95%|█████████▌| 19/20 [00:01<00:00, 20.10it/s]
# 100%|██████████| 20/20 [00:01<00:00, 17.36it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:16 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:16 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:16 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:16 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:16 | [INFO    ]   Number of images: 22
# 2025-06-09 10:18:16 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:16 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:16 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:16 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:16 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:16 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:16 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:16 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:16 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:17 | [INFO    ] Features extracted!
# 2025-06-09 10:18:17 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:17 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:17 | [INFO    ] Matching features...
# 2025-06-09 10:18:17 | [INFO    ]
#
# Matching failed for batch 5
#
# Processing batch 7 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_6
# Running command from temp_matching/batch_6: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.62it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 18.09it/s]
#  59%|█████▉    | 13/22 [00:00<00:00, 33.53it/s]
#  95%|█████████▌| 21/22 [00:00<00:00, 47.10it/s]
# 100%|██████████| 22/22 [00:00<00:00, 35.55it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.61it/s]
#  20%|██        | 4/20 [00:00<00:01, 10.77it/s]
#  30%|███       | 6/20 [00:00<00:01, 12.29it/s]
#  40%|████      | 8/20 [00:00<00:00, 13.45it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 17.72it/s]
#  70%|███████   | 14/20 [00:00<00:00, 18.74it/s]
#  85%|████████▌ | 17/20 [00:01<00:00, 19.85it/s]
# 100%|██████████| 20/20 [00:01<00:00, 21.15it/s]
# 100%|██████████| 20/20 [00:01<00:00, 16.74it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:21 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:21 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:21 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:21 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:21 | [INFO    ]   Number of images: 22
# 2025-06-09 10:18:21 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:21 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:21 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:21 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:21 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:21 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:21 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:21 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:21 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:21 | [INFO    ] Features extracted!
# 2025-06-09 10:18:21 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:21 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:21 | [INFO    ] Matching features...
# 2025-06-09 10:18:21 | [INFO    ]
#
# Matching failed for batch 6
#
# Processing batch 8 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_7
# Running command from temp_matching/batch_7: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.67it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 19.26it/s]
#  59%|█████▉    | 13/22 [00:00<00:00, 34.71it/s]
#  91%|█████████ | 20/22 [00:00<00:00, 44.72it/s]
# 100%|██████████| 22/22 [00:00<00:00, 35.70it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 17.25it/s]
#  30%|███       | 6/20 [00:00<00:00, 25.44it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 14.24it/s]
#  60%|██████    | 12/20 [00:00<00:00, 17.39it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 18.46it/s]
#  90%|█████████ | 18/20 [00:00<00:00, 18.93it/s]
# 100%|██████████| 20/20 [00:01<00:00, 18.47it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:25 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:25 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:25 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:25 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:25 | [INFO    ]   Number of images: 22
# 2025-06-09 10:18:25 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:25 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:25 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:25 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:25 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:25 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:25 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:25 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:25 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:26 | [INFO    ] Features extracted!
# 2025-06-09 10:18:26 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:26 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:26 | [INFO    ] Matching features...
# 2025-06-09 10:18:26 | [INFO    ]
#
# Matching failed for batch 7
#
# Processing batch 9 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_8
# Running command from temp_matching/batch_8: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.70it/s]
#  32%|███▏      | 7/22 [00:00<00:00, 22.58it/s]
#  68%|██████▊   | 15/22 [00:00<00:00, 39.62it/s]
# 100%|██████████| 22/22 [00:00<00:00, 38.21it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 15.54it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 19.62it/s]
#  40%|████      | 8/20 [00:00<00:00, 22.31it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 15.86it/s]
#  70%|███████   | 14/20 [00:00<00:00, 17.60it/s]
#  80%|████████  | 16/20 [00:00<00:00, 18.06it/s]
#  90%|█████████ | 18/20 [00:00<00:00, 18.42it/s]
# 100%|██████████| 20/20 [00:01<00:00, 18.40it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:30 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:30 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:30 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:30 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:30 | [INFO    ]   Number of images: 22
# 2025-06-09 10:18:30 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:30 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:30 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:30 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:30 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:30 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:30 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:30 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:30 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:30 | [INFO    ] Features extracted!
# 2025-06-09 10:18:30 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:30 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:30 | [INFO    ] Matching features...
# 2025-06-09 10:18:30 | [INFO    ]
#
# Matching failed for batch 8
#
# Processing batch 10 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_9
# Running command from temp_matching/batch_9: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/21 [00:00<?, ?it/s]
#   5%|▍         | 1/21 [00:00<00:05,  3.42it/s]
#  29%|██▊       | 6/21 [00:00<00:00, 18.67it/s]
#  67%|██████▋   | 14/21 [00:00<00:00, 36.57it/s]
# 100%|██████████| 21/21 [00:00<00:00, 35.00it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:04,  3.87it/s]
#  20%|██        | 4/20 [00:00<00:01, 11.58it/s]
#  30%|███       | 6/20 [00:00<00:01, 13.96it/s]
#  40%|████      | 8/20 [00:00<00:00, 15.68it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 23.76it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 26.79it/s]
# 100%|██████████| 20/20 [00:00<00:00, 21.41it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:34 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:34 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:34 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:34 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:34 | [INFO    ]   Number of images: 21
# 2025-06-09 10:18:34 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:34 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:34 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:34 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:34 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:34 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:34 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:34 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:34 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:35 | [INFO    ] Features extracted!
# 2025-06-09 10:18:35 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:35 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:35 | [INFO    ] Matching features...
# 2025-06-09 10:18:35 | [INFO    ]
#
# Matching failed for batch 9
#
# Processing batch 11 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_10
# Running command from temp_matching/batch_10: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.69it/s]
#  40%|████      | 8/20 [00:00<00:00, 25.71it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 39.23it/s]
# 100%|██████████| 20/20 [00:00<00:00, 35.46it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 16.28it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 23.25it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 29.92it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 29.20it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 31.74it/s]
# 100%|██████████| 20/20 [00:00<00:00, 30.71it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:38 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:38 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:38 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:38 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:38 | [INFO    ]   Number of images: 20
# 2025-06-09 10:18:38 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:38 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:38 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:38 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:38 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:38 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:38 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:38 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:38 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:39 | [INFO    ] Features extracted!
# 2025-06-09 10:18:39 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:39 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:39 | [INFO    ] Matching features...
# 2025-06-09 10:18:39 | [INFO    ]
#
# Matching failed for batch 10
#
# Processing batch 12 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_11
# Running command from temp_matching/batch_11: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/19 [00:00<?, ?it/s]
#   5%|▌         | 1/19 [00:00<00:04,  3.72it/s]
#  37%|███▋      | 7/19 [00:00<00:00, 22.47it/s]
#  74%|███████▎  | 14/19 [00:00<00:00, 37.77it/s]
# 100%|██████████| 19/19 [00:00<00:00, 35.00it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 16.45it/s]
#  30%|███       | 6/20 [00:00<00:00, 27.18it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 26.25it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 29.03it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 32.07it/s]
# 100%|██████████| 20/20 [00:00<00:00, 29.59it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:42 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:42 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:42 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:42 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:42 | [INFO    ]   Number of images: 19
# 2025-06-09 10:18:42 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:42 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:42 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:42 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:42 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:42 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:42 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:42 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:42 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:43 | [INFO    ] Features extracted!
# 2025-06-09 10:18:43 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:43 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:43 | [INFO    ] Matching features...
# 2025-06-09 10:18:43 | [INFO    ]
#
# Matching failed for batch 11
#
# Processing batch 13 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_12
# Running command from temp_matching/batch_12: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#   6%|▌         | 1/18 [00:00<00:04,  3.68it/s]
#  44%|████▍     | 8/18 [00:00<00:00, 25.51it/s]
#  89%|████████▉ | 16/18 [00:00<00:00, 42.16it/s]
# 100%|██████████| 18/18 [00:00<00:00, 35.04it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:00, 18.15it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 22.67it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 28.81it/s]
#  70%|███████   | 14/20 [00:00<00:00, 36.02it/s]
#  90%|█████████ | 18/20 [00:00<00:00, 34.96it/s]
# 100%|██████████| 20/20 [00:00<00:00, 32.67it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:46 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:46 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:46 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:46 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:46 | [INFO    ]   Number of images: 18
# 2025-06-09 10:18:46 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:46 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:46 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:46 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:46 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:46 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:46 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:46 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:46 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:47 | [INFO    ] Features extracted!
# 2025-06-09 10:18:47 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:47 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:47 | [INFO    ] Matching features...
# 2025-06-09 10:18:47 | [INFO    ]
#
# Matching failed for batch 12
#
# Processing batch 14 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_13
# Running command from temp_matching/batch_13: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/16 [00:00<?, ?it/s]
#   6%|▋         | 1/16 [00:00<00:03,  3.76it/s]
#  50%|█████     | 8/16 [00:00<00:00, 25.44it/s]
#  94%|█████████▍| 15/16 [00:00<00:00, 39.55it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.12it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:02,  8.52it/s]
#  20%|██        | 4/20 [00:00<00:01, 14.77it/s]
#  30%|███       | 6/20 [00:00<00:00, 16.30it/s]
#  50%|█████     | 10/20 [00:00<00:00, 22.26it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 22.22it/s]
#  80%|████████  | 16/20 [00:00<00:00, 20.63it/s]
#  95%|█████████▌| 19/20 [00:00<00:00, 19.85it/s]
# 100%|██████████| 20/20 [00:01<00:00, 19.69it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:50 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:50 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:50 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:50 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:50 | [INFO    ]   Number of images: 16
# 2025-06-09 10:18:50 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:50 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:50 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:50 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:50 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:50 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:50 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:50 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:50 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:50 | [INFO    ] Features extracted!
# 2025-06-09 10:18:50 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:50 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:50 | [INFO    ] Matching features...
# 2025-06-09 10:18:50 | [INFO    ]
#
# Matching failed for batch 13
#
# Processing batch 15 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_14
# Running command from temp_matching/batch_14: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/15 [00:00<?, ?it/s]
#   7%|▋         | 1/15 [00:00<00:03,  3.85it/s]
#  47%|████▋     | 7/15 [00:00<00:00, 23.48it/s]
# 100%|██████████| 15/15 [00:00<00:00, 41.46it/s]
# 100%|██████████| 15/15 [00:00<00:00, 31.94it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:00, 18.04it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 22.28it/s]
#  40%|████      | 8/20 [00:00<00:00, 20.69it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 19.73it/s]
#  70%|███████   | 14/20 [00:00<00:00, 20.83it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 22.94it/s]
# 100%|██████████| 20/20 [00:00<00:00, 22.99it/s]
# 100%|██████████| 20/20 [00:00<00:00, 21.86it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:54 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:54 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:54 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:54 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:54 | [INFO    ]   Number of images: 15
# 2025-06-09 10:18:54 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:54 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:54 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:54 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:54 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:54 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:54 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:54 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:54 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:55 | [INFO    ] Features extracted!
# 2025-06-09 10:18:55 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:55 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:55 | [INFO    ] Matching features...
# 2025-06-09 10:18:55 | [INFO    ]
#
# Matching failed for batch 14
#
# Processing batch 16 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_15
# Running command from temp_matching/batch_15: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/13 [00:00<?, ?it/s]
#   8%|▊         | 1/13 [00:00<00:03,  3.80it/s]
#  62%|██████▏   | 8/13 [00:00<00:00, 26.09it/s]
# 100%|██████████| 13/13 [00:00<00:00, 29.02it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 13.38it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 21.28it/s]
#  40%|████      | 8/20 [00:00<00:00, 22.28it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 20.46it/s]
#  70%|███████   | 14/20 [00:00<00:00, 20.74it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 22.60it/s]
# 100%|██████████| 20/20 [00:00<00:00, 23.08it/s]
# 100%|██████████| 20/20 [00:00<00:00, 21.75it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:18:58 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:18:58 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:18:58 | [INFO    ]   Image folder: images
# 2025-06-09 10:18:58 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:18:58 | [INFO    ]   Number of images: 13
# 2025-06-09 10:18:58 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:18:58 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:18:58 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:18:58 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:18:58 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:18:58 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:18:58 | [INFO    ]   CUDA available: True
# 2025-06-09 10:18:58 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:18:58 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:18:59 | [INFO    ] Features extracted!
# 2025-06-09 10:18:59 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:18:59 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:18:59 | [INFO    ] Matching features...
# 2025-06-09 10:18:59 | [INFO    ]
#
# Matching failed for batch 15
#
# Processing batch 17 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_16
# Running command from temp_matching/batch_16: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/12 [00:00<?, ?it/s]
#   8%|▊         | 1/12 [00:00<00:02,  3.87it/s]
#  67%|██████▋   | 8/12 [00:00<00:00, 26.85it/s]
# 100%|██████████| 12/12 [00:00<00:00, 28.31it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 14.69it/s]
#  20%|██        | 4/20 [00:00<00:00, 16.19it/s]
#  30%|███       | 6/20 [00:00<00:00, 17.23it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 21.51it/s]
#  60%|██████    | 12/20 [00:00<00:00, 21.69it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 23.10it/s]
#  90%|█████████ | 18/20 [00:00<00:00, 23.22it/s]
# 100%|██████████| 20/20 [00:00<00:00, 21.57it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:19:02 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:19:02 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:19:02 | [INFO    ]   Image folder: images
# 2025-06-09 10:19:02 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:19:02 | [INFO    ]   Number of images: 12
# 2025-06-09 10:19:02 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:19:02 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:19:02 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:19:02 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:19:02 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:19:02 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:19:02 | [INFO    ]   CUDA available: True
# 2025-06-09 10:19:02 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:19:02 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:19:03 | [INFO    ] Features extracted!
# 2025-06-09 10:19:03 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:19:03 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:19:03 | [INFO    ] Matching features...
# 2025-06-09 10:19:03 | [INFO    ]
#
# Matching failed for batch 16
#
# Processing batch 18 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_17
# Running command from temp_matching/batch_17: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:02,  3.71it/s]
#  80%|████████  | 8/10 [00:00<00:00, 26.10it/s]
# 100%|██████████| 10/10 [00:00<00:00, 24.96it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 14.49it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 21.08it/s]
#  40%|████      | 8/20 [00:00<00:00, 22.76it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 23.18it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 25.90it/s]
#  95%|█████████▌| 19/20 [00:00<00:00, 28.19it/s]
# 100%|██████████| 20/20 [00:00<00:00, 25.50it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:19:06 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:19:06 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:19:06 | [INFO    ]   Image folder: images
# 2025-06-09 10:19:06 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:19:06 | [INFO    ]   Number of images: 10
# 2025-06-09 10:19:06 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:19:06 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:19:06 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:19:06 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:19:06 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:19:06 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:19:06 | [INFO    ]   CUDA available: True
# 2025-06-09 10:19:06 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:19:06 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:19:07 | [INFO    ] Features extracted!
# 2025-06-09 10:19:07 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:19:07 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:19:07 | [INFO    ] Matching features...
# 2025-06-09 10:19:07 | [INFO    ]
#
# Matching failed for batch 17
#
# Processing batch 19 (18 pairs)...
# Setup completed for 18 pairs in temp_matching/batch_18
# Running command from temp_matching/batch_18: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.79it/s]
# 100%|██████████| 7/7 [00:00<00:00, 19.25it/s]
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#  11%|█         | 2/18 [00:00<00:01, 16.00it/s]
#  28%|██▊       | 5/18 [00:00<00:00, 21.03it/s]
#  44%|████▍     | 8/18 [00:00<00:00, 24.34it/s]
#  61%|██████    | 11/18 [00:00<00:00, 25.19it/s]
#  83%|████████▎ | 15/18 [00:00<00:00, 29.73it/s]
# 100%|██████████| 18/18 [00:00<00:00, 28.39it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:19:10 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:19:10 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:19:10 | [INFO    ]   Image folder: images
# 2025-06-09 10:19:10 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:19:10 | [INFO    ]   Number of images: 7
# 2025-06-09 10:19:10 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:19:10 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:19:10 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:19:10 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:19:10 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:19:10 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:19:10 | [INFO    ]   CUDA available: True
# 2025-06-09 10:19:10 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:19:10 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:19:10 | [INFO    ] Features extracted!
# 2025-06-09 10:19:10 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:19:10 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:19:10 | [INFO    ] Matching features...
# 2025-06-09 10:19:10 | [INFO    ]
#
# Matching failed for batch 18
# No results to save!

# %%
# Out:
# Starting comprehensive signature matching...
# Total pairs to process: 378
# Same person pairs: 74
# Different person pairs: 304
#
# Processing batch 1 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_0
# Running command from temp_matching/batch_0: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/21 [00:00<?, ?it/s]
#   5%|▍         | 1/21 [00:00<00:05,  3.59it/s]
#  24%|██▍       | 5/21 [00:00<00:01, 15.48it/s]
#  48%|████▊     | 10/21 [00:00<00:00, 25.80it/s]
#  81%|████████  | 17/21 [00:00<00:00, 38.47it/s]
# 100%|██████████| 21/21 [00:00<00:00, 32.37it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.60it/s]
#  15%|█▌        | 3/20 [00:00<00:02,  7.21it/s]
#  25%|██▌       | 5/20 [00:00<00:01,  8.93it/s]
#  35%|███▌      | 7/20 [00:00<00:01,  9.57it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 15.41it/s]
#  65%|██████▌   | 13/20 [00:01<00:00, 16.38it/s]
#  75%|███████▌  | 15/20 [00:01<00:00, 17.27it/s]
#  85%|████████▌ | 17/20 [00:01<00:00, 17.94it/s]
#  95%|█████████▌| 19/20 [00:01<00:00, 18.22it/s]
# 100%|██████████| 20/20 [00:01<00:00, 14.15it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:23:27 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:23:28 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:23:28 | [INFO    ]   Image folder: images
# 2025-06-09 10:23:28 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:23:28 | [INFO    ]   Number of images: 21
# 2025-06-09 10:23:28 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:23:28 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:23:28 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:23:28 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:23:28 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:23:28 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:23:28 | [INFO    ]   CUDA available: True
# 2025-06-09 10:23:28 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:23:28 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:23:28 | [INFO    ] Features extracted!
# 2025-06-09 10:23:28 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:23:28 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:23:28 | [INFO    ] Matching features...
# 2025-06-09 10:23:28 | [INFO    ]
#
# Matching failed for batch 0
#
# Processing batch 2 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_1
# Running command from temp_matching/batch_1: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.59it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 18.48it/s]
#  55%|█████▍    | 12/22 [00:00<00:00, 31.08it/s]
#  86%|████████▋ | 19/22 [00:00<00:00, 42.46it/s]
# 100%|██████████| 22/22 [00:00<00:00, 34.23it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:04,  3.89it/s]
#  15%|█▌        | 3/20 [00:00<00:01,  9.53it/s]
#  30%|███       | 6/20 [00:00<00:00, 15.98it/s]
#  40%|████      | 8/20 [00:00<00:00, 16.27it/s]
#  50%|█████     | 10/20 [00:00<00:00, 14.05it/s]
#  60%|██████    | 12/20 [00:00<00:00, 13.33it/s]
#  70%|███████   | 14/20 [00:01<00:00, 14.54it/s]
#  90%|█████████ | 18/20 [00:01<00:00, 19.23it/s]
# 100%|██████████| 20/20 [00:01<00:00, 15.62it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:23:33 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:23:33 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:23:33 | [INFO    ]   Image folder: images
# 2025-06-09 10:23:33 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:23:33 | [INFO    ]   Number of images: 22
# 2025-06-09 10:23:33 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:23:33 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:23:33 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:23:33 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:23:33 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:23:33 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:23:33 | [INFO    ]   CUDA available: True
# 2025-06-09 10:23:33 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:23:33 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:23:34 | [INFO    ] Features extracted!
# 2025-06-09 10:23:34 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:23:34 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:23:34 | [INFO    ] Matching features...
# 2025-06-09 10:23:34 | [INFO    ]
#
# Matching failed for batch 1
#
# Processing batch 3 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_2
# Running command from temp_matching/batch_2: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.69it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 18.85it/s]
#  55%|█████▍    | 12/22 [00:00<00:00, 30.89it/s]
#  91%|█████████ | 20/22 [00:00<00:00, 44.87it/s]
# 100%|██████████| 22/22 [00:00<00:00, 35.05it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.71it/s]
#  15%|█▌        | 3/20 [00:00<00:01,  9.05it/s]
#  25%|██▌       | 5/20 [00:00<00:01, 12.19it/s]
#  40%|████      | 8/20 [00:00<00:00, 15.17it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 18.86it/s]
#  70%|███████   | 14/20 [00:00<00:00, 19.37it/s]
#  85%|████████▌ | 17/20 [00:01<00:00, 17.10it/s]
#  95%|█████████▌| 19/20 [00:01<00:00, 16.88it/s]
# 100%|██████████| 20/20 [00:01<00:00, 15.75it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:23:38 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:23:38 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:23:38 | [INFO    ]   Image folder: images
# 2025-06-09 10:23:38 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:23:38 | [INFO    ]   Number of images: 22
# 2025-06-09 10:23:38 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:23:38 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:23:38 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:23:38 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:23:38 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:23:38 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:23:38 | [INFO    ]   CUDA available: True
# 2025-06-09 10:23:38 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:23:38 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:23:39 | [INFO    ] Features extracted!
# 2025-06-09 10:23:39 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:23:39 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:23:39 | [INFO    ] Matching features...
# 2025-06-09 10:23:39 | [INFO    ]
#
# Matching failed for batch 2
#
# Processing batch 4 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_3
# Running command from temp_matching/batch_3: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.77it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 19.72it/s]
#  59%|█████▉    | 13/22 [00:00<00:00, 35.57it/s]
#  91%|█████████ | 20/22 [00:00<00:00, 46.32it/s]
# 100%|██████████| 22/22 [00:00<00:00, 36.64it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 17.40it/s]
#  20%|██        | 4/20 [00:00<00:00, 18.19it/s]
#  30%|███       | 6/20 [00:00<00:00, 18.85it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 19.56it/s]
#  60%|██████    | 12/20 [00:00<00:00, 20.64it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 22.46it/s]
#  95%|█████████▌| 19/20 [00:01<00:00, 16.57it/s]
# 100%|██████████| 20/20 [00:01<00:00, 17.62it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:23:42 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:23:43 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:23:43 | [INFO    ]   Image folder: images
# 2025-06-09 10:23:43 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:23:43 | [INFO    ]   Number of images: 22
# 2025-06-09 10:23:43 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:23:43 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:23:43 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:23:43 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:23:43 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:23:43 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:23:43 | [INFO    ]   CUDA available: True
# 2025-06-09 10:23:43 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:23:43 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:23:43 | [INFO    ] Features extracted!
# 2025-06-09 10:23:43 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:23:43 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:23:43 | [INFO    ] Matching features...
# 2025-06-09 10:23:43 | [INFO    ]
#
# Matching failed for batch 3
#
# Processing batch 5 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_4
# Running command from temp_matching/batch_4: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/21 [00:00<?, ?it/s]
#   5%|▍         | 1/21 [00:00<00:05,  3.53it/s]
#  33%|███▎      | 7/21 [00:00<00:00, 21.32it/s]
#  67%|██████▋   | 14/21 [00:00<00:00, 36.00it/s]
# 100%|██████████| 21/21 [00:00<00:00, 35.61it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:03,  5.73it/s]
#  25%|██▌       | 5/20 [00:00<00:01, 12.36it/s]
#  40%|████      | 8/20 [00:00<00:00, 15.87it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 17.38it/s]
#  70%|███████   | 14/20 [00:00<00:00, 18.43it/s]
#  85%|████████▌ | 17/20 [00:01<00:00, 20.04it/s]
# 100%|██████████| 20/20 [00:01<00:00, 22.05it/s]
# 100%|██████████| 20/20 [00:01<00:00, 17.80it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:23:47 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:23:47 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:23:47 | [INFO    ]   Image folder: images
# 2025-06-09 10:23:47 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:23:47 | [INFO    ]   Number of images: 21
# 2025-06-09 10:23:47 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:23:47 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:23:47 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:23:47 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:23:47 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:23:47 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:23:47 | [INFO    ]   CUDA available: True
# 2025-06-09 10:23:47 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:23:47 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:23:48 | [INFO    ] Features extracted!
# 2025-06-09 10:23:48 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:23:48 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:23:48 | [INFO    ] Matching features...
# 2025-06-09 10:23:48 | [INFO    ]
#
# Matching failed for batch 4
#
# Processing batch 6 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_5
# Running command from temp_matching/batch_5: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.74it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 19.32it/s]
#  59%|█████▉    | 13/22 [00:00<00:00, 34.80it/s]
#  95%|█████████▌| 21/22 [00:00<00:00, 48.06it/s]
# 100%|██████████| 22/22 [00:00<00:00, 36.67it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 15.17it/s]
#  20%|██        | 4/20 [00:00<00:02,  7.99it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 13.12it/s]
#  50%|█████     | 10/20 [00:00<00:00, 16.91it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 18.52it/s]
#  80%|████████  | 16/20 [00:00<00:00, 20.21it/s]
#  95%|█████████▌| 19/20 [00:01<00:00, 21.55it/s]
# 100%|██████████| 20/20 [00:01<00:00, 17.95it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:23:51 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:23:51 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:23:51 | [INFO    ]   Image folder: images
# 2025-06-09 10:23:51 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:23:51 | [INFO    ]   Number of images: 22
# 2025-06-09 10:23:51 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:23:51 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:23:51 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:23:51 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:23:51 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:23:51 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:23:51 | [INFO    ]   CUDA available: True
# 2025-06-09 10:23:51 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:23:51 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:23:52 | [INFO    ] Features extracted!
# 2025-06-09 10:23:52 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:23:52 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:23:52 | [INFO    ] Matching features...
# 2025-06-09 10:23:52 | [INFO    ]
#
# Matching failed for batch 5
#
# Processing batch 7 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_6
# Running command from temp_matching/batch_6: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.59it/s]
#  23%|██▎       | 5/22 [00:00<00:01, 15.66it/s]
#  55%|█████▍    | 12/22 [00:00<00:00, 32.02it/s]
#  91%|█████████ | 20/22 [00:00<00:00, 45.58it/s]
# 100%|██████████| 22/22 [00:00<00:00, 35.17it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.61it/s]
#  20%|██        | 4/20 [00:00<00:01, 11.81it/s]
#  30%|███       | 6/20 [00:00<00:01, 13.22it/s]
#  40%|████      | 8/20 [00:00<00:00, 14.21it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 18.45it/s]
#  70%|███████   | 14/20 [00:00<00:00, 19.31it/s]
#  85%|████████▌ | 17/20 [00:01<00:00, 20.15it/s]
# 100%|██████████| 20/20 [00:01<00:00, 21.33it/s]
# 100%|██████████| 20/20 [00:01<00:00, 17.28it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:23:56 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:23:56 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:23:56 | [INFO    ]   Image folder: images
# 2025-06-09 10:23:56 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:23:56 | [INFO    ]   Number of images: 22
# 2025-06-09 10:23:56 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:23:56 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:23:56 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:23:56 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:23:56 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:23:56 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:23:56 | [INFO    ]   CUDA available: True
# 2025-06-09 10:23:56 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:23:56 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:23:57 | [INFO    ] Features extracted!
# 2025-06-09 10:23:57 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:23:57 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:23:57 | [INFO    ] Matching features...
# 2025-06-09 10:23:57 | [INFO    ]
#
# Matching failed for batch 6
#
# Processing batch 8 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_7
# Running command from temp_matching/batch_7: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.64it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 19.50it/s]
#  59%|█████▉    | 13/22 [00:00<00:00, 35.19it/s]
#  91%|█████████ | 20/22 [00:00<00:00, 45.86it/s]
# 100%|██████████| 22/22 [00:00<00:00, 36.43it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 17.60it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 32.71it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 17.43it/s]
#  70%|███████   | 14/20 [00:00<00:00, 18.90it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 19.35it/s]
# 100%|██████████| 20/20 [00:01<00:00, 19.72it/s]
# 100%|██████████| 20/20 [00:01<00:00, 19.90it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:00 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:00 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:00 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:00 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:00 | [INFO    ]   Number of images: 22
# 2025-06-09 10:24:00 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:00 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:00 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:00 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:00 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:00 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:00 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:00 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:00 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:01 | [INFO    ] Features extracted!
# 2025-06-09 10:24:01 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:01 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:01 | [INFO    ] Matching features...
# 2025-06-09 10:24:01 | [INFO    ]
#
# Matching failed for batch 7
#
# Processing batch 9 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_8
# Running command from temp_matching/batch_8: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.64it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 19.04it/s]
#  64%|██████▎   | 14/22 [00:00<00:00, 37.49it/s]
# 100%|██████████| 22/22 [00:00<00:00, 37.20it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 14.16it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 18.61it/s]
#  40%|████      | 8/20 [00:00<00:00, 20.81it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 15.18it/s]
#  70%|███████   | 14/20 [00:00<00:00, 17.20it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 19.05it/s]
# 100%|██████████| 20/20 [00:01<00:00, 20.58it/s]
# 100%|██████████| 20/20 [00:01<00:00, 18.84it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:04 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:05 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:05 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:05 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:05 | [INFO    ]   Number of images: 22
# 2025-06-09 10:24:05 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:05 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:05 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:05 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:05 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:05 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:05 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:05 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:05 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:05 | [INFO    ] Features extracted!
# 2025-06-09 10:24:05 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:05 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:05 | [INFO    ] Matching features...
# 2025-06-09 10:24:05 | [INFO    ]
#
# Matching failed for batch 8
#
# Processing batch 10 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_9
# Running command from temp_matching/batch_9: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/21 [00:00<?, ?it/s]
#   5%|▍         | 1/21 [00:00<00:05,  3.47it/s]
#  33%|███▎      | 7/21 [00:00<00:00, 22.04it/s]
#  67%|██████▋   | 14/21 [00:00<00:00, 37.24it/s]
# 100%|██████████| 21/21 [00:00<00:00, 36.46it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.75it/s]
#  20%|██        | 4/20 [00:00<00:01, 11.38it/s]
#  30%|███       | 6/20 [00:00<00:01, 13.64it/s]
#  40%|████      | 8/20 [00:00<00:00, 15.19it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 23.26it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 26.33it/s]
# 100%|██████████| 20/20 [00:00<00:00, 20.93it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:09 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:09 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:09 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:09 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:09 | [INFO    ]   Number of images: 21
# 2025-06-09 10:24:09 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:09 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:09 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:09 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:09 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:09 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:09 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:09 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:09 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:09 | [INFO    ] Features extracted!
# 2025-06-09 10:24:09 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:09 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:09 | [INFO    ] Matching features...
# 2025-06-09 10:24:09 | [INFO    ]
#
# Matching failed for batch 9
#
# Processing batch 11 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_10
# Running command from temp_matching/batch_10: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.62it/s]
#  40%|████      | 8/20 [00:00<00:00, 25.43it/s]
#  80%|████████  | 16/20 [00:00<00:00, 42.12it/s]
# 100%|██████████| 20/20 [00:00<00:00, 37.24it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 16.23it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 23.15it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 29.98it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 29.32it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 32.10it/s]
# 100%|██████████| 20/20 [00:00<00:00, 29.46it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:13 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:13 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:13 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:13 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:13 | [INFO    ]   Number of images: 20
# 2025-06-09 10:24:13 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:13 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:13 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:13 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:13 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:13 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:13 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:13 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:13 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:14 | [INFO    ] Features extracted!
# 2025-06-09 10:24:14 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:14 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:14 | [INFO    ] Matching features...
# 2025-06-09 10:24:14 | [INFO    ]
#
# Matching failed for batch 10
#
# Processing batch 12 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_11
# Running command from temp_matching/batch_11: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/19 [00:00<?, ?it/s]
#   5%|▌         | 1/19 [00:00<00:05,  3.45it/s]
#  37%|███▋      | 7/19 [00:00<00:00, 21.80it/s]
#  74%|███████▎  | 14/19 [00:00<00:00, 35.52it/s]
# 100%|██████████| 19/19 [00:00<00:00, 32.94it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 15.02it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 22.15it/s]
#  40%|████      | 8/20 [00:00<00:00, 25.26it/s]
#  60%|██████    | 12/20 [00:00<00:00, 27.67it/s]
#  80%|████████  | 16/20 [00:00<00:00, 28.90it/s]
#  95%|█████████▌| 19/20 [00:00<00:00, 28.78it/s]
# 100%|██████████| 20/20 [00:00<00:00, 27.11it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:17 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:17 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:17 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:17 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:17 | [INFO    ]   Number of images: 19
# 2025-06-09 10:24:17 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:17 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:17 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:17 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:17 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:17 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:17 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:17 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:17 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:18 | [INFO    ] Features extracted!
# 2025-06-09 10:24:18 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:18 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:18 | [INFO    ] Matching features...
# 2025-06-09 10:24:18 | [INFO    ]
#
# Matching failed for batch 11
#
# Processing batch 13 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_12
# Running command from temp_matching/batch_12: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#   6%|▌         | 1/18 [00:00<00:04,  3.63it/s]
#  39%|███▉      | 7/18 [00:00<00:00, 22.69it/s]
#  83%|████████▎ | 15/18 [00:00<00:00, 39.99it/s]
# 100%|██████████| 18/18 [00:00<00:00, 34.28it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 17.61it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 21.94it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 27.96it/s]
#  70%|███████   | 14/20 [00:00<00:00, 31.98it/s]
#  90%|█████████ | 18/20 [00:00<00:00, 31.95it/s]
# 100%|██████████| 20/20 [00:00<00:00, 30.44it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:21 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:21 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:21 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:21 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:21 | [INFO    ]   Number of images: 18
# 2025-06-09 10:24:21 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:21 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:21 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:21 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:21 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:21 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:21 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:21 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:21 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:22 | [INFO    ] Features extracted!
# 2025-06-09 10:24:22 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:22 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:22 | [INFO    ] Matching features...
# 2025-06-09 10:24:22 | [INFO    ]
#
# Matching failed for batch 12
#
# Processing batch 14 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_13
# Running command from temp_matching/batch_13: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/16 [00:00<?, ?it/s]
#   6%|▋         | 1/16 [00:00<00:03,  3.81it/s]
#  50%|█████     | 8/16 [00:00<00:00, 25.93it/s]
# 100%|██████████| 16/16 [00:00<00:00, 42.02it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.88it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:02,  8.58it/s]
#  20%|██        | 4/20 [00:00<00:01, 14.86it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 18.48it/s]
#  50%|█████     | 10/20 [00:00<00:00, 21.81it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 22.15it/s]
#  80%|████████  | 16/20 [00:00<00:00, 20.93it/s]
#  95%|█████████▌| 19/20 [00:00<00:00, 20.28it/s]
# 100%|██████████| 20/20 [00:00<00:00, 20.25it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:25 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:25 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:25 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:25 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:25 | [INFO    ]   Number of images: 16
# 2025-06-09 10:24:25 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:25 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:25 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:25 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:25 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:25 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:25 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:25 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:25 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:25 | [INFO    ] Features extracted!
# 2025-06-09 10:24:25 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:25 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:25 | [INFO    ] Matching features...
# 2025-06-09 10:24:25 | [INFO    ]
#
# Matching failed for batch 13
#
# Processing batch 15 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_14
# Running command from temp_matching/batch_14: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/15 [00:00<?, ?it/s]
#   7%|▋         | 1/15 [00:00<00:03,  3.83it/s]
#  53%|█████▎    | 8/15 [00:00<00:00, 26.07it/s]
# 100%|██████████| 15/15 [00:00<00:00, 32.19it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:00, 18.52it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 21.68it/s]
#  40%|████      | 8/20 [00:00<00:00, 20.00it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 19.13it/s]
#  70%|███████   | 14/20 [00:00<00:00, 20.45it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 22.71it/s]
# 100%|██████████| 20/20 [00:00<00:00, 22.77it/s]
# 100%|██████████| 20/20 [00:00<00:00, 21.52it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:29 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:29 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:29 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:29 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:29 | [INFO    ]   Number of images: 15
# 2025-06-09 10:24:29 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:29 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:29 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:29 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:29 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:29 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:29 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:29 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:29 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:30 | [INFO    ] Features extracted!
# 2025-06-09 10:24:30 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:30 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:30 | [INFO    ] Matching features...
# 2025-06-09 10:24:30 | [INFO    ]
#
# Matching failed for batch 14
#
# Processing batch 16 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_15
# Running command from temp_matching/batch_15: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/13 [00:00<?, ?it/s]
#   8%|▊         | 1/13 [00:00<00:03,  3.67it/s]
#  62%|██████▏   | 8/13 [00:00<00:00, 25.61it/s]
# 100%|██████████| 13/13 [00:00<00:00, 28.65it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 13.54it/s]
#  30%|███       | 6/20 [00:00<00:00, 23.13it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 24.11it/s]
#  60%|██████    | 12/20 [00:00<00:00, 23.92it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 24.09it/s]
#  90%|█████████ | 18/20 [00:00<00:00, 25.48it/s]
# 100%|██████████| 20/20 [00:00<00:00, 24.40it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:33 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:33 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:33 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:33 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:33 | [INFO    ]   Number of images: 13
# 2025-06-09 10:24:33 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:33 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:33 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:33 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:33 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:33 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:33 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:33 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:33 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:34 | [INFO    ] Features extracted!
# 2025-06-09 10:24:34 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:34 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:34 | [INFO    ] Matching features...
# 2025-06-09 10:24:34 | [INFO    ]
#
# Matching failed for batch 15
#
# Processing batch 17 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_16
# Running command from temp_matching/batch_16: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/12 [00:00<?, ?it/s]
#   8%|▊         | 1/12 [00:00<00:03,  3.60it/s]
#  67%|██████▋   | 8/12 [00:00<00:00, 25.50it/s]
# 100%|██████████| 12/12 [00:00<00:00, 27.16it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 14.50it/s]
#  20%|██        | 4/20 [00:00<00:01, 15.99it/s]
#  30%|███       | 6/20 [00:00<00:00, 17.21it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 21.43it/s]
#  60%|██████    | 12/20 [00:00<00:00, 21.42it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 22.71it/s]
#  90%|█████████ | 18/20 [00:00<00:00, 22.77it/s]
# 100%|██████████| 20/20 [00:00<00:00, 21.15it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:37 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:37 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:37 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:37 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:37 | [INFO    ]   Number of images: 12
# 2025-06-09 10:24:37 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:37 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:37 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:37 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:37 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:37 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:37 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:37 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:37 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:38 | [INFO    ] Features extracted!
# 2025-06-09 10:24:38 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:38 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:38 | [INFO    ] Matching features...
# 2025-06-09 10:24:38 | [INFO    ]
#
# Matching failed for batch 16
#
# Processing batch 18 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_17
# Running command from temp_matching/batch_17: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:02,  3.76it/s]
#  80%|████████  | 8/10 [00:00<00:00, 26.88it/s]
# 100%|██████████| 10/10 [00:00<00:00, 25.62it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 14.71it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 19.92it/s]
#  40%|████      | 8/20 [00:00<00:00, 21.24it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 21.82it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 24.95it/s]
#  95%|█████████▌| 19/20 [00:00<00:00, 28.55it/s]
# 100%|██████████| 20/20 [00:00<00:00, 25.05it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:41 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:41 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:41 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:41 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:41 | [INFO    ]   Number of images: 10
# 2025-06-09 10:24:41 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:41 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:41 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:41 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:41 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:41 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:41 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:41 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:41 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:42 | [INFO    ] Features extracted!
# 2025-06-09 10:24:42 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:42 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:42 | [INFO    ] Matching features...
# 2025-06-09 10:24:42 | [INFO    ]
#
# Matching failed for batch 17
#
# Processing batch 19 (18 pairs)...
# Setup completed for 18 pairs in temp_matching/batch_18
# Running command from temp_matching/batch_18: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.65it/s]
# 100%|██████████| 7/7 [00:00<00:00, 19.14it/s]
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#  11%|█         | 2/18 [00:00<00:01, 15.55it/s]
#  28%|██▊       | 5/18 [00:00<00:00, 22.15it/s]
#  50%|█████     | 9/18 [00:00<00:00, 28.86it/s]
#  67%|██████▋   | 12/18 [00:00<00:00, 27.50it/s]
#  94%|█████████▍| 17/18 [00:00<00:00, 33.11it/s]
# 100%|██████████| 18/18 [00:00<00:00, 29.97it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:24:45 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:24:45 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:24:45 | [INFO    ]   Image folder: images
# 2025-06-09 10:24:45 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:24:45 | [INFO    ]   Number of images: 7
# 2025-06-09 10:24:45 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:24:45 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:24:45 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:24:45 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:24:45 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:24:45 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:24:45 | [INFO    ]   CUDA available: True
# 2025-06-09 10:24:45 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:24:45 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:24:46 | [INFO    ] Features extracted!
# 2025-06-09 10:24:46 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:24:46 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:24:46 | [INFO    ] Matching features...
# 2025-06-09 10:24:46 | [INFO    ]
#
# Matching failed for batch 18
# No results to save!

# %%
# comprehensive_signature_matching_fixed.py
import os
import itertools
import pandas as pd
from pathlib import Path
import shutil
import subprocess
import sys
import h5py
import numpy as np
import cv2
import matplotlib.pyplot as plt
from datetime import datetime

class SignatureMatchingSystem:
    def __init__(self, real_data_dir="real_data", temp_dir="temp_matching", results_dir="matching_results"):
        self.real_data_dir = Path(real_data_dir)
        self.temp_dir = Path(temp_dir)
        self.results_dir = Path(results_dir)
        
        # Create necessary directories
        self.temp_dir.mkdir(exist_ok=True)
        self.results_dir.mkdir(exist_ok=True)
        
        # Results tracking
        self.results_log = []
        
    def get_all_image_pairs(self):
        """Generate all possible pairs of images across all subfolders"""
        all_images = []
        
        # Collect all images with their person ID
        for person_folder in self.real_data_dir.iterdir():
            if person_folder.is_dir():
                person_id = person_folder.name
                for img_file in person_folder.iterdir():
                    if img_file.suffix.lower() in ['.png', '.jpg', '.jpeg']:
                        all_images.append({
                            'person_id': person_id,
                            'image_path': img_file,
                            'image_name': img_file.name,
                            'full_name': f"{person_id}_{img_file.name}"
                        })
        
        # Generate all pairs
        pairs = []
        for img1, img2 in itertools.combinations(all_images, 2):
            pairs.append({
                'img1': img1,
                'img2': img2,
                'same_person': img1['person_id'] == img2['person_id'],
                'pair_name': f"{img1['full_name']}_vs_{img2['full_name']}"
            })
            
        return pairs
    
    def create_pair_batch(self, pairs, batch_size=50):
        """Create batches of pairs for processing"""
        for i in range(0, len(pairs), batch_size):
            yield pairs[i:i + batch_size]
    
    def setup_batch_directory(self, batch_pairs, batch_id):
        """Setup batch directory with proper structure for main.py"""
        batch_temp_dir = self.temp_dir / f"batch_{batch_id}"
        
        # Clean up existing directory
        if batch_temp_dir.exists():
            shutil.rmtree(batch_temp_dir)
        batch_temp_dir.mkdir(exist_ok=True)
        
        # Create 'images' subdirectory as expected by main.py
        images_dir = batch_temp_dir / "images"
        images_dir.mkdir(exist_ok=True)
        
        # Copy images to images subdirectory
        copied_images = set()
        pair_lines = []
        
        for pair in batch_pairs:
            # Copy images if not already copied
            for img_key in ['img1', 'img2']:
                img_info = pair[img_key]
                new_name = img_info['full_name']
                
                if new_name not in copied_images:
                    src_path = img_info['image_path']
                    dst_path = images_dir / new_name
                    shutil.copy2(src_path, dst_path)
                    copied_images.add(new_name)
            
            # Add pair to pairs.txt
            pair_lines.append(f"{pair['img1']['full_name']} {pair['img2']['full_name']}")
        
        # Write pairs.txt in batch directory
        pairs_file = batch_temp_dir / "pairs.txt"
        with open(pairs_file, 'w') as f:
            f.write('\n'.join(pair_lines))
        
        return batch_temp_dir, len(pair_lines)
    
    def run_matching_for_batch(self, batch_temp_dir):
        """Run the main.py script for a batch with corrected command"""
        original_cwd = os.getcwd()
        
        try:
            # Change to batch directory and run main.py from original location
            cmd = [
                sys.executable, 
                str(Path(original_cwd) / "main.py"),  # Full path to main.py
                "-d", ".",  # Current directory (batch directory)
                "-p", "superpoint+lightglue",
                "-s", "custom_pairs",
                "--pair_file", "pairs.txt",
                "-f"
            ]
            
            print(f"Running command from {batch_temp_dir}: {' '.join(cmd)}")
            
            # Run from batch directory
            result = subprocess.run(cmd, capture_output=True, text=True, cwd=str(batch_temp_dir))
            
            if result.returncode != 0:
                print(f"Error running matching: {result.stderr}")
                print(f"stdout: {result.stdout}")
                return False
            else:
                print(f"Matching completed successfully")
                print(f"stdout: {result.stdout}")
            
            return True
            
        except Exception as e:
            print(f"Exception during matching: {e}")
            return False
    
    def load_keypoints_and_scores(self, h5file, image_name):
        """Load keypoints and their confidence scores from features file"""
        try:
            with h5py.File(h5file, "r") as f:
                if image_name in f:
                    keypoints = f[image_name]["keypoints"][()]
                    scores = f[image_name]["scores"][()]
                    return keypoints, scores
                else:
                    return None, None
        except Exception as e:
            print(f"Error loading keypoints for {image_name}: {e}")
            return None, None
    
    def load_matches(self, h5file, image_name1, image_name2):
        """Load matches between two images with proper error handling"""
        try:
            with h5py.File(h5file, "r") as f:
                # Try both orders
                if image_name1 in f and image_name2 in f[image_name1]:
                    matches = f[image_name1][image_name2][()]
                    return matches if len(matches) > 0 else None
                elif image_name2 in f and image_name1 in f[image_name2]:
                    matches = f[image_name2][image_name1][()]
                    return matches if len(matches) > 0 else None
                else:
                    return None
        except Exception as e:
            print(f"Error loading matches between {image_name1} and {image_name2}: {e}")
            return None
    
    def create_signature_mask(self, image_path, blur_kernel=3, threshold_value=240):
        """Create a binary mask to identify signature regions"""
        try:
            img = cv2.imread(str(image_path), cv2.IMREAD_GRAYSCALE)
            if img is None:
                return None
            
            blurred = cv2.GaussianBlur(img, (blur_kernel, blur_kernel), 0)
            _, mask = cv2.threshold(blurred, threshold_value, 255, cv2.THRESH_BINARY_INV)
            
            kernel = np.ones((3, 3), np.uint8)
            mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
            mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
            
            return mask
        except Exception as e:
            print(f"Error creating mask for {image_path}: {e}")
            return None
    
    def filter_keypoints_by_signature(self, keypoints, scores, mask, dilation_radius=10):
        """Filter keypoints to keep only those that lie on or near signature strokes"""
        if mask is None or len(keypoints) == 0:
            return np.array([]), np.array([]), np.array([])
        
        try:
            kernel = cv2.getStructuringElement(
                cv2.MORPH_ELLIPSE, (dilation_radius * 2 + 1, dilation_radius * 2 + 1)
            )
            dilated_mask = cv2.dilate(mask, kernel, iterations=1)
            
            valid_indices = []
            for i, (x, y) in enumerate(keypoints):
                x_int, y_int = int(round(x)), int(round(y))
                if 0 <= x_int < dilated_mask.shape[1] and 0 <= y_int < dilated_mask.shape[0]:
                    if dilated_mask[y_int, x_int] > 0:
                        valid_indices.append(i)
            
            valid_indices = np.array(valid_indices)
            
            if len(valid_indices) > 0:
                filtered_keypoints = keypoints[valid_indices]
                filtered_scores = scores[valid_indices]
                return filtered_keypoints, filtered_scores, valid_indices
            else:
                return np.array([]), np.array([]), np.array([])
        except Exception as e:
            print(f"Error filtering keypoints: {e}")
            return np.array([]), np.array([]), np.array([])
    
    def filter_matches_by_signature_features(self, matches, valid_indices1, valid_indices2):
        """Filter matches to keep only those between signature features"""
        if matches is None or len(matches) == 0 or len(valid_indices1) == 0 or len(valid_indices2) == 0:
            return np.array([])
        
        try:
            idx1_map = {orig_idx: new_idx for new_idx, orig_idx in enumerate(valid_indices1)}
            idx2_map = {orig_idx: new_idx for new_idx, orig_idx in enumerate(valid_indices2)}
            
            filtered_matches = []
            for match in matches:
                idx1, idx2 = match[0], match[1]
                if idx1 in idx1_map and idx2 in idx2_map:
                    filtered_matches.append([idx1_map[idx1], idx2_map[idx2]])
            
            return np.array(filtered_matches)
        except Exception as e:
            print(f"Error filtering matches: {e}")
            return np.array([])
    
    def visualize_matches(self, img1_path, img2_path, keypoints1, keypoints2, 
                         original_matches, filtered_keypoints1, filtered_keypoints2, 
                         filtered_matches, pair_info, save_path):
        """Create and save visualization of matches"""
        try:
            print(f"    Loading images: {img1_path}, {img2_path}")
            img1 = cv2.imread(str(img1_path))
            img2 = cv2.imread(str(img2_path))
            
            if img1 is None or img2 is None:
                print(f"    ERROR: Could not load images: {img1_path}, {img2_path}")
                return False
            
            print(f"    Images loaded successfully. Shape1: {img1.shape}, Shape2: {img2.shape}")
            
            fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 16))
            
            # Plot 1: Original matches
            if original_matches is not None and len(original_matches) > 0:
                print(f"    Creating original matches visualization ({len(original_matches)} matches)")
                kpts1_orig = [cv2.KeyPoint(float(x), float(y), 1) for x, y in keypoints1]
                kpts2_orig = [cv2.KeyPoint(float(x), float(y), 1) for x, y in keypoints2]
                
                cv_matches_orig = [
                    cv2.DMatch(_queryIdx=int(i), _trainIdx=int(j), _distance=0) 
                    for i, j in original_matches
                ]
                
                img_matches_orig = cv2.drawMatches(
                    img1, kpts1_orig, img2, kpts2_orig, cv_matches_orig, None,
                    flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS,
                )
                
                ax1.imshow(cv2.cvtColor(img_matches_orig, cv2.COLOR_BGR2RGB))
                ax1.set_title(f"Original Feature Matches ({len(original_matches)} matches)", fontsize=16)
            else:
                print(f"    No original matches to display")
                ax1.text(0.5, 0.5, "No original matches found", ha='center', va='center', 
                        transform=ax1.transAxes, fontsize=16)
            ax1.axis("off")
            
            # Plot 2: Signature matches
            if (filtered_matches is not None and len(filtered_matches) > 0 and 
                len(filtered_keypoints1) > 0 and len(filtered_keypoints2) > 0):
                
                print(f"    Creating signature matches visualization ({len(filtered_matches)} matches)")
                kpts1_filt = [cv2.KeyPoint(float(x), float(y), 1) for x, y in filtered_keypoints1]
                kpts2_filt = [cv2.KeyPoint(float(x), float(y), 1) for x, y in filtered_keypoints2]
                
                cv_matches_filt = [
                    cv2.DMatch(_queryIdx=int(i), _trainIdx=int(j), _distance=0) 
                    for i, j in filtered_matches
                ]
                
                img_matches_filt = cv2.drawMatches(
                    img1, kpts1_filt, img2, kpts2_filt, cv_matches_filt, None,
                    flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS,
                )
                
                ax2.imshow(cv2.cvtColor(img_matches_filt, cv2.COLOR_BGR2RGB))
                ax2.set_title(f"Signature Feature Matches ({len(filtered_matches)} matches)", fontsize=16)
            else:
                print(f"    No signature matches to display")
                ax2.text(0.5, 0.5, "No signature matches found", ha='center', va='center', 
                        transform=ax2.transAxes, fontsize=16)
            ax2.axis("off")
            
            # Add pair information
            same_person_text = "SAME PERSON" if pair_info['same_person'] else "DIFFERENT PERSON"
            fig.suptitle(f"{pair_info['pair_name']} - {same_person_text}", fontsize=18, y=0.98)
            
            plt.tight_layout()
            
            # Ensure directory exists
            save_path.parent.mkdir(parents=True, exist_ok=True)
            
            print(f"    Saving visualization to: {save_path}")
            plt.savefig(save_path, dpi=150, bbox_inches='tight')
            plt.close()
            
            print(f"    Visualization saved successfully!")
            return True
            
        except Exception as e:
            print(f"    ERROR creating visualization: {e}")
            import traceback
            traceback.print_exc()
            return False
    
    def find_results_files(self, batch_temp_dir):
        """Find the results files (features.h5 and matches.h5) in the batch directory"""
        # Look for results directory created by main.py
        results_dirs = list(batch_temp_dir.glob("results_*"))
        
        if results_dirs:
            results_dir = results_dirs[0]  # Take the first (should be only one)
            features_path = results_dir / "features.h5"
            matches_path = results_dir / "matches.h5"
        else:
            # Sometimes files might be created directly in the batch directory
            features_path = batch_temp_dir / "features.h5"
            matches_path = batch_temp_dir / "matches.h5"
        
        return features_path, matches_path
    
    def process_batch_results(self, batch_pairs, batch_temp_dir, batch_id):
        """Process results from a batch"""
        features_path, matches_path = self.find_results_files(batch_temp_dir)
        
        if not features_path.exists() or not matches_path.exists():
            print(f"Missing features ({features_path.exists()}) or matches ({matches_path.exists()}) file for batch {batch_id}")
            print(f"Looking in: {batch_temp_dir}")
            # List all files in the directory for debugging
            print("Files found:")
            for file in batch_temp_dir.rglob("*"):
                print(f"  {file}")
            return
        
        batch_results_dir = self.results_dir / f"batch_{batch_id}"
        batch_results_dir.mkdir(exist_ok=True)
        
        batch_log = []
        
        for pair in batch_pairs:
            try:
                img1_name = pair['img1']['full_name']
                img2_name = pair['img2']['full_name']
                
                print(f"Processing pair: {img1_name} vs {img2_name}")
                
                # Load keypoints
                keypoints1, scores1 = self.load_keypoints_and_scores(features_path, img1_name)
                keypoints2, scores2 = self.load_keypoints_and_scores(features_path, img2_name)
                
                if keypoints1 is None or keypoints2 is None:
                    print(f"Failed to load keypoints for {img1_name} or {img2_name}")
                    continue
                
                # Load matches
                original_matches = self.load_matches(matches_path, img1_name, img2_name)
                
                # Create signature masks
                img1_path = batch_temp_dir / "images" / img1_name
                img2_path = batch_temp_dir / "images" / img2_name
                
                mask1 = self.create_signature_mask(img1_path)
                mask2 = self.create_signature_mask(img2_path)
                
                # Filter keypoints by signature regions
                filt_kpts1, filt_scores1, valid_idx1 = self.filter_keypoints_by_signature(
                    keypoints1, scores1, mask1
                )
                filt_kpts2, filt_scores2, valid_idx2 = self.filter_keypoints_by_signature(
                    keypoints2, scores2, mask2
                )
                
                # Filter matches
                filtered_matches = self.filter_matches_by_signature_features(
                    original_matches, valid_idx1, valid_idx2
                )
                
                # Create visualization
                viz_path = batch_results_dir / f"{pair['pair_name']}.png"
                print(f"  Creating visualization: {viz_path}")
                viz_success = self.visualize_matches(
                    img1_path, img2_path, keypoints1, keypoints2,
                    original_matches, filt_kpts1, filt_kpts2, filtered_matches,
                    pair, viz_path
                )
                print(f"  Visualization success: {viz_success}")
                
                # Log results
                result_entry = {
                    'pair_name': pair['pair_name'],
                    'img1': img1_name,
                    'img2': img2_name,
                    'same_person': pair['same_person'],
                    'person1_id': pair['img1']['person_id'],
                    'person2_id': pair['img2']['person_id'],
                    'original_features_1': len(keypoints1),
                    'original_features_2': len(keypoints2),
                    'signature_features_1': len(filt_kpts1),
                    'signature_features_2': len(filt_kpts2),
                    'original_matches': len(original_matches) if original_matches is not None else 0,
                    'signature_matches': len(filtered_matches) if filtered_matches is not None else 0,
                    'visualization_created': viz_success,
                    'visualization_path': str(viz_path) if viz_success else None,
                    'batch_id': batch_id,
                    'timestamp': datetime.now().isoformat()
                }
                
                batch_log.append(result_entry)
                self.results_log.append(result_entry)
                
                print(f"  Original matches: {result_entry['original_matches']}")
                print(f"  Signature matches: {result_entry['signature_matches']}")
                print(f"  Visualization saved: {viz_path if viz_success else 'FAILED'}")
                
            except Exception as e:
                print(f"Error processing pair {pair['pair_name']}: {e}")
                continue
        
        # Save batch results
        if batch_log:
            batch_df = pd.DataFrame(batch_log)
            batch_df.to_csv(batch_results_dir / "batch_results.csv", index=False)
    
    def run_comprehensive_matching(self, batch_size=20):
        """Run comprehensive signature matching across all pairs"""
        print("Starting comprehensive signature matching...")
        
        # Get all possible pairs
        all_pairs = self.get_all_image_pairs()
        print(f"Total pairs to process: {len(all_pairs)}")
        
        same_person_pairs = sum(1 for p in all_pairs if p['same_person'])
        different_person_pairs = len(all_pairs) - same_person_pairs
        print(f"Same person pairs: {same_person_pairs}")
        print(f"Different person pairs: {different_person_pairs}")
        
        # Process in batches
        for batch_id, batch_pairs in enumerate(self.create_pair_batch(all_pairs, batch_size)):
            print(f"\nProcessing batch {batch_id + 1} ({len(batch_pairs)} pairs)...")
            
            try:
                # Setup batch directory
                batch_temp_dir, num_pairs = self.setup_batch_directory(batch_pairs, batch_id)
                print(f"Setup completed for {num_pairs} pairs in {batch_temp_dir}")
                
                # Run matching
                success = self.run_matching_for_batch(batch_temp_dir)
                if not success:
                    print(f"Matching failed for batch {batch_id}")
                    continue
                
                # Process results
                self.process_batch_results(batch_pairs, batch_temp_dir, batch_id)
                
                # Clean up temporary files (optional - comment out for debugging)
                # shutil.rmtree(batch_temp_dir)
                
            except Exception as e:
                print(f"Error processing batch {batch_id}: {e}")
                continue
        
        # Save comprehensive results
        if self.results_log:
            comprehensive_df = pd.DataFrame(self.results_log)
            comprehensive_df.to_csv(self.results_dir / "comprehensive_results.csv", index=False)
            
            # Generate summary statistics
            self.generate_summary_report(comprehensive_df)
        else:
            print("No results to save!")
    
    def generate_summary_report(self, df):
        """Generate a summary report of matching results"""
        summary = {
            'total_pairs': len(df),
            'same_person_pairs': len(df[df['same_person'] == True]),
            'different_person_pairs': len(df[df['same_person'] == False]),
            'pairs_with_original_matches': len(df[df['original_matches'] > 0]),
            'pairs_with_signature_matches': len(df[df['signature_matches'] > 0]),
            'avg_original_matches_same_person': df[df['same_person'] == True]['original_matches'].mean(),
            'avg_original_matches_different_person': df[df['same_person'] == False]['original_matches'].mean(),
            'avg_signature_matches_same_person': df[df['same_person'] == True]['signature_matches'].mean(),
            'avg_signature_matches_different_person': df[df['same_person'] == False]['signature_matches'].mean(),
        }
        
        # Save summary
        summary_df = pd.DataFrame([summary])
        summary_df.to_csv(self.results_dir / "summary_report.csv", index=False)
        
        # Print summary
        print("\n" + "="*60)
        print("COMPREHENSIVE MATCHING SUMMARY")
        print("="*60)
        for key, value in summary.items():
            print(f"{key.replace('_', ' ').title()}: {value:.2f}" if isinstance(value, float) else f"{key.replace('_', ' ').title()}: {value}")
        print("="*60)


# Usage
if __name__ == "__main__":
    # Initialize the matching system
    matcher = SignatureMatchingSystem(
        real_data_dir="real_data",
        temp_dir="temp_matching", 
        results_dir="matching_results"
    )
    
    # Run comprehensive matching
    matcher.run_comprehensive_matching(batch_size=20)
# Out:
# Starting comprehensive signature matching...
# Total pairs to process: 378
# Same person pairs: 74
# Different person pairs: 304
#
# Processing batch 1 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_0
# Running command from temp_matching/batch_0: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/21 [00:00<?, ?it/s]
#   5%|▍         | 1/21 [00:00<00:06,  3.16it/s]
#  24%|██▍       | 5/21 [00:00<00:01, 14.34it/s]
#  48%|████▊     | 10/21 [00:00<00:00, 25.03it/s]
#  71%|███████▏  | 15/21 [00:00<00:00, 32.01it/s]
# 100%|██████████| 21/21 [00:00<00:00, 39.74it/s]
# 100%|██████████| 21/21 [00:00<00:00, 28.55it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.43it/s]
#  15%|█▌        | 3/20 [00:00<00:02,  6.87it/s]
#  25%|██▌       | 5/20 [00:00<00:01,  8.76it/s]
#  35%|███▌      | 7/20 [00:00<00:01,  9.72it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 16.09it/s]
#  65%|██████▌   | 13/20 [00:01<00:00, 16.68it/s]
#  75%|███████▌  | 15/20 [00:01<00:00, 17.49it/s]
#  90%|█████████ | 18/20 [00:01<00:00, 18.43it/s]
# 100%|██████████| 20/20 [00:01<00:00, 18.22it/s]
# 100%|██████████| 20/20 [00:01<00:00, 14.19it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:31:52 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:31:52 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:31:52 | [INFO    ]   Image folder: images
# 2025-06-09 10:31:52 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:31:52 | [INFO    ]   Number of images: 21
# 2025-06-09 10:31:52 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:31:52 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:31:52 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:31:52 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:31:52 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:31:52 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:31:52 | [INFO    ]   CUDA available: True
# 2025-06-09 10:31:52 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:31:52 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:31:53 | [INFO    ] Features extracted!
# 2025-06-09 10:31:53 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:31:53 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:31:53 | [INFO    ] Matching features...
# 2025-06-09 10:31:53 | [INFO    ]
#
# Matching failed for batch 0
#
# Processing batch 2 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_1
# Running command from temp_matching/batch_1: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.74it/s]
#  23%|██▎       | 5/22 [00:00<00:01, 16.03it/s]
#  50%|█████     | 11/22 [00:00<00:00, 29.02it/s]
#  82%|████████▏ | 18/22 [00:00<00:00, 41.54it/s]
# 100%|██████████| 22/22 [00:00<00:00, 34.13it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.53it/s]
#  15%|█▌        | 3/20 [00:00<00:01,  8.69it/s]
#  30%|███       | 6/20 [00:00<00:00, 14.94it/s]
#  40%|████      | 8/20 [00:00<00:00, 15.57it/s]
#  50%|█████     | 10/20 [00:00<00:00, 13.48it/s]
#  60%|██████    | 12/20 [00:00<00:00, 12.87it/s]
#  70%|███████   | 14/20 [00:01<00:00, 14.22it/s]
#  90%|█████████ | 18/20 [00:01<00:00, 19.04it/s]
# 100%|██████████| 20/20 [00:01<00:00, 15.09it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:31:57 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:31:57 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:31:57 | [INFO    ]   Image folder: images
# 2025-06-09 10:31:57 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:31:57 | [INFO    ]   Number of images: 22
# 2025-06-09 10:31:57 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:31:57 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:31:57 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:31:57 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:31:57 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:31:57 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:31:57 | [INFO    ]   CUDA available: True
# 2025-06-09 10:31:57 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:31:57 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:31:58 | [INFO    ] Features extracted!
# 2025-06-09 10:31:58 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:31:58 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:31:58 | [INFO    ] Matching features...
# 2025-06-09 10:31:58 | [INFO    ]
#
# Matching failed for batch 1
#
# Processing batch 3 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_2
# Running command from temp_matching/batch_2: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.59it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 18.55it/s]
#  55%|█████▍    | 12/22 [00:00<00:00, 30.76it/s]
#  86%|████████▋ | 19/22 [00:00<00:00, 42.68it/s]
# 100%|██████████| 22/22 [00:00<00:00, 34.29it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.60it/s]
#  15%|█▌        | 3/20 [00:00<00:01,  8.78it/s]
#  25%|██▌       | 5/20 [00:00<00:01, 11.80it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 14.06it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 15.64it/s]
#  70%|███████   | 14/20 [00:00<00:00, 21.10it/s]
#  85%|████████▌ | 17/20 [00:01<00:00, 17.90it/s]
#  95%|█████████▌| 19/20 [00:01<00:00, 17.32it/s]
# 100%|██████████| 20/20 [00:01<00:00, 15.71it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:02 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:02 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:02 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:02 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:02 | [INFO    ]   Number of images: 22
# 2025-06-09 10:32:02 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:02 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:02 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:02 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:02 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:02 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:02 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:02 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:02 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:03 | [INFO    ] Features extracted!
# 2025-06-09 10:32:03 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:03 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:03 | [INFO    ] Matching features...
# 2025-06-09 10:32:03 | [INFO    ]
#
# Matching failed for batch 2
#
# Processing batch 4 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_3
# Running command from temp_matching/batch_3: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:06,  3.16it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 17.24it/s]
#  55%|█████▍    | 12/22 [00:00<00:00, 30.01it/s]
#  82%|████████▏ | 18/22 [00:00<00:00, 36.86it/s]
# 100%|██████████| 22/22 [00:00<00:00, 31.40it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:01,  9.96it/s]
#  15%|█▌        | 3/20 [00:00<00:01, 15.75it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 17.42it/s]
#  40%|████      | 8/20 [00:00<00:00, 18.83it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 20.19it/s]
#  70%|███████   | 14/20 [00:00<00:00, 22.58it/s]
#  95%|█████████▌| 19/20 [00:01<00:00, 17.76it/s]
# 100%|██████████| 20/20 [00:01<00:00, 17.64it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:06 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:07 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:07 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:07 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:07 | [INFO    ]   Number of images: 22
# 2025-06-09 10:32:07 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:07 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:07 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:07 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:07 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:07 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:07 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:07 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:07 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:07 | [INFO    ] Features extracted!
# 2025-06-09 10:32:07 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:07 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:07 | [INFO    ] Matching features...
# 2025-06-09 10:32:07 | [INFO    ]
#
# Matching failed for batch 3
#
# Processing batch 5 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_4
# Running command from temp_matching/batch_4: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/21 [00:00<?, ?it/s]
#   5%|▍         | 1/21 [00:00<00:05,  3.66it/s]
#  29%|██▊       | 6/21 [00:00<00:00, 19.39it/s]
#  62%|██████▏   | 13/21 [00:00<00:00, 34.93it/s]
# 100%|██████████| 21/21 [00:00<00:00, 48.14it/s]
# 100%|██████████| 21/21 [00:00<00:00, 35.56it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:02,  6.09it/s]
#  25%|██▌       | 5/20 [00:00<00:01, 12.73it/s]
#  40%|████      | 8/20 [00:00<00:00, 16.16it/s]
#  50%|█████     | 10/20 [00:00<00:00, 17.10it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 18.27it/s]
#  80%|████████  | 16/20 [00:00<00:00, 19.63it/s]
#  95%|█████████▌| 19/20 [00:01<00:00, 21.08it/s]
# 100%|██████████| 20/20 [00:01<00:00, 17.77it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:11 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:11 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:11 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:11 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:11 | [INFO    ]   Number of images: 21
# 2025-06-09 10:32:11 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:11 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:11 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:11 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:11 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:11 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:11 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:11 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:11 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:12 | [INFO    ] Features extracted!
# 2025-06-09 10:32:12 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:12 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:12 | [INFO    ] Matching features...
# 2025-06-09 10:32:12 | [INFO    ]
#
# Matching failed for batch 4
#
# Processing batch 6 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_5
# Running command from temp_matching/batch_5: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:06,  3.31it/s]
#  23%|██▎       | 5/22 [00:00<00:01, 14.80it/s]
#  55%|█████▍    | 12/22 [00:00<00:00, 30.68it/s]
#  86%|████████▋ | 19/22 [00:00<00:00, 41.65it/s]
# 100%|██████████| 22/22 [00:00<00:00, 33.44it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 14.82it/s]
#  20%|██        | 4/20 [00:00<00:02,  7.69it/s]
#  35%|███▌      | 7/20 [00:00<00:01, 12.69it/s]
#  50%|█████     | 10/20 [00:00<00:00, 16.04it/s]
#  60%|██████    | 12/20 [00:00<00:00, 16.72it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 17.59it/s]
#  90%|█████████ | 18/20 [00:01<00:00, 19.35it/s]
# 100%|██████████| 20/20 [00:01<00:00, 16.67it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:16 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:16 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:16 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:16 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:16 | [INFO    ]   Number of images: 22
# 2025-06-09 10:32:16 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:16 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:16 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:16 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:16 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:16 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:16 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:16 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:16 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:17 | [INFO    ] Features extracted!
# 2025-06-09 10:32:17 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:17 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:17 | [INFO    ] Matching features...
# 2025-06-09 10:32:17 | [INFO    ]
#
# Matching failed for batch 5
#
# Processing batch 7 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_6
# Running command from temp_matching/batch_6: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.56it/s]
#  23%|██▎       | 5/22 [00:00<00:01, 15.02it/s]
#  45%|████▌     | 10/22 [00:00<00:00, 24.60it/s]
#  68%|██████▊   | 15/22 [00:00<00:00, 31.47it/s]
#  86%|████████▋ | 19/22 [00:00<00:00, 33.15it/s]
# 100%|██████████| 22/22 [00:00<00:00, 28.27it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:05,  3.51it/s]
#  20%|██        | 4/20 [00:00<00:01, 11.03it/s]
#  30%|███       | 6/20 [00:00<00:01, 12.58it/s]
#  40%|████      | 8/20 [00:00<00:00, 13.28it/s]
#  60%|██████    | 12/20 [00:00<00:00, 18.45it/s]
#  70%|███████   | 14/20 [00:00<00:00, 18.51it/s]
#  85%|████████▌ | 17/20 [00:01<00:00, 19.51it/s]
# 100%|██████████| 20/20 [00:01<00:00, 20.85it/s]
# 100%|██████████| 20/20 [00:01<00:00, 16.67it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:20 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:21 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:21 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:21 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:21 | [INFO    ]   Number of images: 22
# 2025-06-09 10:32:21 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:21 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:21 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:21 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:21 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:21 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:21 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:21 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:21 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:21 | [INFO    ] Features extracted!
# 2025-06-09 10:32:21 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:21 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:21 | [INFO    ] Matching features...
# 2025-06-09 10:32:21 | [INFO    ]
#
# Matching failed for batch 6
#
# Processing batch 8 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_7
# Running command from temp_matching/batch_7: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:05,  3.53it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 18.36it/s]
#  55%|█████▍    | 12/22 [00:00<00:00, 30.79it/s]
#  86%|████████▋ | 19/22 [00:00<00:00, 41.94it/s]
# 100%|██████████| 22/22 [00:00<00:00, 34.19it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:02,  9.25it/s]
#  20%|██        | 4/20 [00:00<00:00, 19.58it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 24.05it/s]
#  50%|█████     | 10/20 [00:00<00:00, 14.58it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 17.10it/s]
#  80%|████████  | 16/20 [00:00<00:00, 18.12it/s]
#  95%|█████████▌| 19/20 [00:01<00:00, 18.86it/s]
# 100%|██████████| 20/20 [00:01<00:00, 18.12it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:25 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:26 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:26 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:26 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:26 | [INFO    ]   Number of images: 22
# 2025-06-09 10:32:26 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:26 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:26 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:26 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:26 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:26 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:26 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:26 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:26 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:26 | [INFO    ] Features extracted!
# 2025-06-09 10:32:26 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:26 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:26 | [INFO    ] Matching features...
# 2025-06-09 10:32:26 | [INFO    ]
#
# Matching failed for batch 7
#
# Processing batch 9 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_8
# Running command from temp_matching/batch_8: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:06,  3.45it/s]
#  27%|██▋       | 6/22 [00:00<00:00, 18.60it/s]
#  59%|█████▉    | 13/22 [00:00<00:00, 34.73it/s]
#  95%|█████████▌| 21/22 [00:00<00:00, 47.91it/s]
# 100%|██████████| 22/22 [00:00<00:00, 35.95it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:01,  9.71it/s]
#  20%|██        | 4/20 [00:00<00:00, 19.31it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 21.21it/s]
#  50%|█████     | 10/20 [00:00<00:00, 14.98it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 17.52it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 17.51it/s]
#  90%|█████████ | 18/20 [00:00<00:00, 19.19it/s]
# 100%|██████████| 20/20 [00:01<00:00, 18.55it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:30 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:30 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:30 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:30 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:30 | [INFO    ]   Number of images: 22
# 2025-06-09 10:32:30 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:30 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:30 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:30 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:30 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:30 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:30 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:30 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:30 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:31 | [INFO    ] Features extracted!
# 2025-06-09 10:32:31 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:31 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:31 | [INFO    ] Matching features...
# 2025-06-09 10:32:31 | [INFO    ]
#
# Matching failed for batch 8
#
# Processing batch 10 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_9
# Running command from temp_matching/batch_9: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/21 [00:00<?, ?it/s]
#   5%|▍         | 1/21 [00:00<00:05,  3.76it/s]
#  33%|███▎      | 7/21 [00:00<00:00, 23.37it/s]
#  71%|███████▏  | 15/21 [00:00<00:00, 40.14it/s]
# 100%|██████████| 21/21 [00:00<00:00, 38.00it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:04,  3.84it/s]
#  20%|██        | 4/20 [00:00<00:01, 11.52it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 15.78it/s]
#  60%|██████    | 12/20 [00:00<00:00, 23.12it/s]
#  80%|████████  | 16/20 [00:00<00:00, 25.80it/s]
# 100%|██████████| 20/20 [00:00<00:00, 28.03it/s]
# 100%|██████████| 20/20 [00:00<00:00, 21.88it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:34 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:35 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:35 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:35 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:35 | [INFO    ]   Number of images: 21
# 2025-06-09 10:32:35 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:35 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:35 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:35 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:35 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:35 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:35 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:35 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:35 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:35 | [INFO    ] Features extracted!
# 2025-06-09 10:32:35 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:35 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:35 | [INFO    ] Matching features...
# 2025-06-09 10:32:35 | [INFO    ]
#
# Matching failed for batch 9
#
# Processing batch 11 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_10
# Running command from temp_matching/batch_10: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:04,  3.88it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 23.01it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 33.14it/s]
# 100%|██████████| 20/20 [00:00<00:00, 43.16it/s]
# 100%|██████████| 20/20 [00:00<00:00, 33.49it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:00, 18.56it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 24.61it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 30.55it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 29.30it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 30.82it/s]
# 100%|██████████| 20/20 [00:00<00:00, 30.36it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:39 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:39 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:39 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:39 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:39 | [INFO    ]   Number of images: 20
# 2025-06-09 10:32:39 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:39 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:39 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:39 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:39 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:39 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:39 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:39 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:39 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:39 | [INFO    ] Features extracted!
# 2025-06-09 10:32:39 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:39 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:39 | [INFO    ] Matching features...
# 2025-06-09 10:32:39 | [INFO    ]
#
# Matching failed for batch 10
#
# Processing batch 12 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_11
# Running command from temp_matching/batch_11: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/19 [00:00<?, ?it/s]
#   5%|▌         | 1/19 [00:00<00:04,  3.86it/s]
#  42%|████▏     | 8/19 [00:00<00:00, 25.99it/s]
#  79%|███████▉  | 15/19 [00:00<00:00, 40.08it/s]
# 100%|██████████| 19/19 [00:00<00:00, 36.24it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 16.31it/s]
#  30%|███       | 6/20 [00:00<00:00, 27.07it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 26.29it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 29.66it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 30.64it/s]
# 100%|██████████| 20/20 [00:00<00:00, 29.26it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:43 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:43 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:43 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:43 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:43 | [INFO    ]   Number of images: 19
# 2025-06-09 10:32:43 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:43 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:43 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:43 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:43 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:43 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:43 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:43 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:43 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:43 | [INFO    ] Features extracted!
# 2025-06-09 10:32:43 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:43 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:43 | [INFO    ] Matching features...
# 2025-06-09 10:32:43 | [INFO    ]
#
# Matching failed for batch 11
#
# Processing batch 13 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_12
# Running command from temp_matching/batch_12: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#   6%|▌         | 1/18 [00:00<00:04,  3.65it/s]
#  44%|████▍     | 8/18 [00:00<00:00, 25.17it/s]
#  83%|████████▎ | 15/18 [00:00<00:00, 39.20it/s]
# 100%|██████████| 18/18 [00:00<00:00, 34.15it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 16.99it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 20.04it/s]
#  40%|████      | 8/20 [00:00<00:00, 22.83it/s]
#  60%|██████    | 12/20 [00:00<00:00, 25.63it/s]
#  80%|████████  | 16/20 [00:00<00:00, 27.33it/s]
# 100%|██████████| 20/20 [00:00<00:00, 29.08it/s]
# 100%|██████████| 20/20 [00:00<00:00, 26.38it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:47 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:47 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:47 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:47 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:47 | [INFO    ]   Number of images: 18
# 2025-06-09 10:32:47 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:47 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:47 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:47 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:47 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:47 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:47 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:47 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:47 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:47 | [INFO    ] Features extracted!
# 2025-06-09 10:32:47 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:47 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:47 | [INFO    ] Matching features...
# 2025-06-09 10:32:47 | [INFO    ]
#
# Matching failed for batch 12
#
# Processing batch 14 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_13
# Running command from temp_matching/batch_13: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/16 [00:00<?, ?it/s]
#   6%|▋         | 1/16 [00:00<00:03,  3.86it/s]
#  50%|█████     | 8/16 [00:00<00:00, 26.03it/s]
#  94%|█████████▍| 15/16 [00:00<00:00, 39.14it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.27it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:02,  8.33it/s]
#  15%|█▌        | 3/20 [00:00<00:01, 14.60it/s]
#  25%|██▌       | 5/20 [00:00<00:01, 14.33it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 21.71it/s]
#  60%|██████    | 12/20 [00:00<00:00, 21.73it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 21.75it/s]
#  90%|█████████ | 18/20 [00:00<00:00, 20.74it/s]
# 100%|██████████| 20/20 [00:01<00:00, 19.85it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:51 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:51 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:51 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:51 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:51 | [INFO    ]   Number of images: 16
# 2025-06-09 10:32:51 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:51 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:51 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:51 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:51 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:51 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:51 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:51 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:51 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:51 | [INFO    ] Features extracted!
# 2025-06-09 10:32:51 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:51 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:51 | [INFO    ] Matching features...
# 2025-06-09 10:32:51 | [INFO    ]
#
# Matching failed for batch 13
#
# Processing batch 15 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_14
# Running command from temp_matching/batch_14: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/15 [00:00<?, ?it/s]
#   7%|▋         | 1/15 [00:00<00:03,  3.79it/s]
#  47%|████▋     | 7/15 [00:00<00:00, 23.49it/s]
# 100%|██████████| 15/15 [00:00<00:00, 41.05it/s]
# 100%|██████████| 15/15 [00:00<00:00, 31.64it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:00, 18.36it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 22.85it/s]
#  40%|████      | 8/20 [00:00<00:00, 20.53it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 19.45it/s]
#  65%|██████▌   | 13/20 [00:00<00:00, 19.25it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 23.13it/s]
# 100%|██████████| 20/20 [00:00<00:00, 22.77it/s]
# 100%|██████████| 20/20 [00:00<00:00, 21.62it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:55 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:55 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:55 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:55 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:55 | [INFO    ]   Number of images: 15
# 2025-06-09 10:32:55 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:55 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:55 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:55 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:55 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:55 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:55 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:55 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:55 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:55 | [INFO    ] Features extracted!
# 2025-06-09 10:32:55 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:55 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:55 | [INFO    ] Matching features...
# 2025-06-09 10:32:55 | [INFO    ]
#
# Matching failed for batch 14
#
# Processing batch 16 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_15
# Running command from temp_matching/batch_15: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/13 [00:00<?, ?it/s]
#   8%|▊         | 1/13 [00:00<00:03,  3.86it/s]
#  62%|██████▏   | 8/13 [00:00<00:00, 26.78it/s]
# 100%|██████████| 13/13 [00:00<00:00, 30.08it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 13.98it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 21.60it/s]
#  40%|████      | 8/20 [00:00<00:00, 22.89it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 22.78it/s]
#  70%|███████   | 14/20 [00:00<00:00, 22.62it/s]
#  85%|████████▌ | 17/20 [00:00<00:00, 24.36it/s]
# 100%|██████████| 20/20 [00:00<00:00, 24.63it/s]
# 100%|██████████| 20/20 [00:00<00:00, 23.23it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:32:59 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:32:59 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:32:59 | [INFO    ]   Image folder: images
# 2025-06-09 10:32:59 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:32:59 | [INFO    ]   Number of images: 13
# 2025-06-09 10:32:59 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:32:59 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:32:59 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:32:59 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:32:59 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:32:59 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:32:59 | [INFO    ]   CUDA available: True
# 2025-06-09 10:32:59 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:32:59 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:32:59 | [INFO    ] Features extracted!
# 2025-06-09 10:32:59 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:32:59 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:32:59 | [INFO    ] Matching features...
# 2025-06-09 10:32:59 | [INFO    ]
#
# Matching failed for batch 15
#
# Processing batch 17 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_16
# Running command from temp_matching/batch_16: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/12 [00:00<?, ?it/s]
#   8%|▊         | 1/12 [00:00<00:02,  3.95it/s]
#  67%|██████▋   | 8/12 [00:00<00:00, 27.71it/s]
# 100%|██████████| 12/12 [00:00<00:00, 29.41it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 15.02it/s]
#  20%|██        | 4/20 [00:00<00:00, 16.56it/s]
#  30%|███       | 6/20 [00:00<00:00, 17.71it/s]
#  45%|████▌     | 9/20 [00:00<00:00, 22.19it/s]
#  60%|██████    | 12/20 [00:00<00:00, 22.24it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 23.79it/s]
#  95%|█████████▌| 19/20 [00:00<00:00, 25.49it/s]
# 100%|██████████| 20/20 [00:00<00:00, 22.73it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:33:03 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:33:03 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:33:03 | [INFO    ]   Image folder: images
# 2025-06-09 10:33:03 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:33:03 | [INFO    ]   Number of images: 12
# 2025-06-09 10:33:03 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:33:03 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:33:03 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:33:03 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:33:03 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:33:03 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:33:03 | [INFO    ]   CUDA available: True
# 2025-06-09 10:33:03 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:33:03 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:33:03 | [INFO    ] Features extracted!
# 2025-06-09 10:33:03 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:33:03 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:33:03 | [INFO    ] Matching features...
# 2025-06-09 10:33:03 | [INFO    ]
#
# Matching failed for batch 16
#
# Processing batch 18 (20 pairs)...
# Setup completed for 20 pairs in temp_matching/batch_17
# Running command from temp_matching/batch_17: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:02,  3.84it/s]
#  90%|█████████ | 9/10 [00:00<00:00, 29.49it/s]
# 100%|██████████| 10/10 [00:00<00:00, 25.94it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:01, 14.87it/s]
#  25%|██▌       | 5/20 [00:00<00:00, 20.21it/s]
#  40%|████      | 8/20 [00:00<00:00, 21.69it/s]
#  55%|█████▌    | 11/20 [00:00<00:00, 22.36it/s]
#  75%|███████▌  | 15/20 [00:00<00:00, 25.34it/s]
#  90%|█████████ | 18/20 [00:00<00:00, 25.98it/s]
# 100%|██████████| 20/20 [00:00<00:00, 24.68it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:33:07 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:33:07 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:33:07 | [INFO    ]   Image folder: images
# 2025-06-09 10:33:07 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:33:07 | [INFO    ]   Number of images: 10
# 2025-06-09 10:33:07 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:33:07 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:33:07 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:33:07 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:33:07 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:33:07 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:33:07 | [INFO    ]   CUDA available: True
# 2025-06-09 10:33:07 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:33:07 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:33:07 | [INFO    ] Features extracted!
# 2025-06-09 10:33:07 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:33:07 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:33:07 | [INFO    ] Matching features...
# 2025-06-09 10:33:07 | [INFO    ]
#
# Matching failed for batch 17
#
# Processing batch 19 (18 pairs)...
# Setup completed for 18 pairs in temp_matching/batch_18
# Running command from temp_matching/batch_18: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/venv/bin/python /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py -d . -p superpoint+lightglue -s custom_pairs --pair_file pairs.txt -f
# Error running matching: /home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/src/deep_image_matching/thirdparty/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.78it/s]
# 100%|██████████| 7/7 [00:00<00:00, 22.74it/s]
# 100%|██████████| 7/7 [00:00<00:00, 18.71it/s]
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#  11%|█         | 2/18 [00:00<00:00, 16.62it/s]
#  33%|███▎      | 6/18 [00:00<00:00, 25.00it/s]
#  50%|█████     | 9/18 [00:00<00:00, 26.38it/s]
#  67%|██████▋   | 12/18 [00:00<00:00, 26.68it/s]
#  94%|█████████▍| 17/18 [00:00<00:00, 32.35it/s]
# 100%|██████████| 18/18 [00:00<00:00, 28.99it/s]
# Traceback (most recent call last):
#   File "/home/kshitiz/Documents/Deep_Image_Matching/deep-image-matching/main.py", line 58, in <module>
#     with open(config.general["camera_options"], "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: './config/cameras.yaml'
#
# stdout: 2025-06-09 10:33:10 | [WARNING ] Not possible to import tkinter
# Loaded SuperPoint model
# 2025-06-09 10:33:11 | [INFO    ] Running image matching with the following configuration:
# 2025-06-09 10:33:11 | [INFO    ]   Image folder: images
# 2025-06-09 10:33:11 | [INFO    ]   Output folder: results_superpoint+lightglue_custom_pairs_quality_high
# 2025-06-09 10:33:11 | [INFO    ]   Number of images: 7
# 2025-06-09 10:33:11 | [INFO    ]   Matching strategy: custom_pairs
# 2025-06-09 10:33:11 | [INFO    ]   Image quality: HIGH
# 2025-06-09 10:33:11 | [INFO    ]   Tile selection: NONE
# 2025-06-09 10:33:11 | [INFO    ]   Feature extraction method: superpoint
# 2025-06-09 10:33:11 | [INFO    ]   Matching method: lightglue
# 2025-06-09 10:33:11 | [INFO    ]   Geometric verification: PYDEGENSAC
# 2025-06-09 10:33:11 | [INFO    ]   CUDA available: True
# 2025-06-09 10:33:11 | [INFO    ] Extracting features with superpoint...
# 2025-06-09 10:33:11 | [INFO    ] superpoint configuration:
# {'keypoint_threshold': 5e-05,
#  'max_keypoints': 4096,
#  'name': 'superpoint',
#  'nms_radius': 3}
# 2025-06-09 10:33:11 | [INFO    ] Features extracted!
# 2025-06-09 10:33:11 | [INFO    ] Matching features with lightglue...
# 2025-06-09 10:33:11 | [INFO    ] lightglue configuration:
# {'depth_confidence': 0.95,
#  'filter_threshold': 0.05,
#  'flash': True,
#  'mp': False,
#  'n_layers': 9,
#  'name': 'lightglue',
#  'width_confidence': 0.99}
# 2025-06-09 10:33:11 | [INFO    ] Matching features...
# 2025-06-09 10:33:11 | [INFO    ]
#
# Matching failed for batch 18
# No results to save!
